# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
from nltk.chunk import ne_chunk
from nltk.stem.snowball import SnowballStemmer
import pandas as pd

# %%
df = pd.read_csv('train.csv',sep=';')

# %%
stemmer = SnowballStemmer("english")

# %%
df.head()
# Out:
#         Word   POS    Tag
# 0  President   NNP  B-per
# 1     Karzai   NNP  I-per
# 2    thanked   VBD      O
# 3        his  PRP$      O
# 4     allies   NNS      O

# %%
def preprocess(sent):
    stemmed = []
    for word in sent:
        stemmed.append(stemmer.stem(word))
    sent = nltk.pos_tag(stemmed)
    return sent

# %%
sent = preprocess(df["Word"].values)
sent
# Out:
# [('presid', 'NN'),
#  ('karzai', 'NN'),
#  ('thank', 'VBD'),
#  ('his', 'PRP$'),
#  ('alli', 'NN'),
#  ('for', 'IN'),
#  ('their', 'PRP$'),
#  ('help', 'NN'),
#  ('in', 'IN'),
#  ('battl', 'JJ'),
#  ('terror', 'NN'),
#  ('.', '.'),
#  ('the', 'DT'),
#  ('command', 'NN'),
#  ('of', 'IN'),
#  ('nato', 'NN'),
#  ("'s", 'POS'),
#  ('afghan', 'NN'),
#  ('forc', 'NN'),
#  (',', ','),
#  ('british', 'JJ'),
#  ('general', 'JJ'),
#  ('david', 'NN'),
#  ('richard', 'NN'),
#  (',', ','),
#  ('said', 'VBD'),
#  ('the', 'DT'),
#  ('uniti', 'NN'),
#  ('of', 'IN'),
#  ('command', 'NN'),
#  ('the', 'DT'),
#  ('transfer', 'NN'),
#  ('brought', 'NN'),
#  ('will', 'MD'),
#  ('enhanc', 'VB'),
#  ('the', 'DT'),
#  ('effect', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('overal', 'JJ'),
#  ('oper', 'NN'),
#  ('.', '.'),
#  ('refer', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('fight', 'NN'),
#  ('in', 'IN'),
#  ('southern', 'JJ'),
#  ('afghanistan', 'JJ'),
#  ('sinc', 'NN'),
#  ('nato', 'NNS'),
#  ('took', 'VBD'),
#  ('command', 'NN'),
#  ('there', 'RB'),
#  ('in', 'IN'),
#  ('juli', 'NN'),
#  (',', ','),
#  ('richard', 'NN'),
#  ('said', 'VBD'),
#  ('the', 'DT'),
#  ('nato', 'NN'),
#  ('forc', 'NN'),
#  ('has', 'VBZ'),
#  ('shown', 'VBN'),
#  ('it', 'PRP'),
#  ('resolv', 'VBZ'),
#  ('to', 'TO'),
#  ('meet', 'VB'),
#  ('the', 'DT'),
#  ('challeng', 'NN'),
#  ('of', 'IN'),
#  ('it', 'PRP'),
#  ('expand', 'DT'),
#  ('mission', 'NN'),
#  ('.', '.'),
#  ('richard', 'NN'),
#  ('was', 'VBD'),
#  ('promot', 'VBN'),
#  ('to', 'TO'),
#  ('four-star', 'JJ'),
#  ('general', 'JJ'),
#  ('hour', 'NN'),
#  ('befor', 'IN'),
#  ('the', 'DT'),
#  ('command', 'NN'),
#  ('chang', 'NN'),
#  ('.', '.'),
#  ('burma', 'NN'),
#  ("'s", 'POS'),
#  ('militari', 'NN'),
#  ('govern', 'NN'),
#  ('said', 'VBD'),
#  ('today', 'NN'),
#  ('that', 'IN'),
#  ('ex-prim', 'JJ'),
#  ('minist', 'NN'),
#  ('khin', 'NN'),
#  ('nyunt', 'NN'),
#  ('was', 'VBD'),
#  ('oust', 'JJ'),
#  ('last', 'JJ'),
#  ('month', 'NN'),
#  ('becaus', 'VBD'),
#  ('his', 'PRP$'),
#  ('investig', 'NN'),
#  ('of', 'IN'),
#  ('militari', 'NN'),
#  ('command', 'NN'),
#  ('threaten', 'VB'),
#  ('the', 'DT'),
#  ('uniti', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('arm', 'NN'),
#  ('forc', 'NN'),
#  ('.', '.'),
#  ('state-control', 'JJ'),
#  ('newspap', 'NN'),
#  ('on', 'IN'),
#  ('sunday', 'JJ'),
#  ('publish', 'VB'),
#  ('a', 'DT'),
#  ('speech', 'NN'),
#  ('deliv', 'NN'),
#  ('octob', 'IN'),
#  ('24', 'CD'),
#  ('by', 'IN'),
#  ('rule', 'NN'),
#  ('council', 'NN'),
#  ('member', 'NN'),
#  ('general', 'JJ'),
#  ('thura', 'NN'),
#  ('shwe', 'NN'),
#  ('mahn', 'NN'),
#  (',', ','),
#  ('who', 'WP'),
#  ('said', 'VBD'),
#  ('khin', 'JJ'),
#  ('nyunt', 'NN'),
#  ('began', 'VBD'),
#  ('investig', 'JJ'),
#  ('rival', 'NN'),
#  ('offic', 'NN'),
#  ('after', 'IN'),
#  ('be', 'VB'),
#  ('told', 'VBN'),
#  ('he', 'PRP'),
#  ('would', 'MD'),
#  ('be', 'VB'),
#  ('replac', 'VBN'),
#  ('as', 'IN'),
#  ('militari', 'NN'),
#  ('intellig', 'NN'),
#  ('chief', 'NN'),
#  ('.', '.'),
#  ('thura', 'NN'),
#  ('shwe', 'NN'),
#  ('mahn', 'NN'),
#  ('said', 'VBD'),
#  ('those', 'DT'),
#  ('action', 'NN'),
#  ('pose', 'VBP'),
#  ('a', 'DT'),
#  ('serious', 'JJ'),
#  ('threat', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('uniti', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('militari', 'NN'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('nation', 'NN'),
#  ('.', '.'),
#  ('he', 'PRP'),
#  ('also', 'RB'),
#  ('told', 'VBD'),
#  ('businessmen', 'NNS'),
#  ('with', 'IN'),
#  ('connect', 'NN'),
#  ('to', 'TO'),
#  ('khin', 'VB'),
#  ('nyunt', 'NN'),
#  ('to', 'TO'),
#  ('disclos', 'VB'),
#  ('that', 'DT'),
#  ('inform', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('rule', 'NN'),
#  ('council', 'NN'),
#  ('.', '.'),
#  ('the', 'DT'),
#  ('former', 'JJ'),
#  ('prime', 'JJ'),
#  ('minist', 'NN'),
#  ('was', 'VBD'),
#  ('replac', 'JJ'),
#  ('octob', 'RB'),
#  ('19', 'CD'),
#  ('by', 'IN'),
#  ('hardlin', 'NN'),
#  ('lieuten', 'JJ'),
#  ('general', 'JJ'),
#  ('soe', 'NN'),
#  ('win', 'NN'),
#  ('.', '.'),
#  ('the', 'DT'),
#  ('chang', 'NN'),
#  ('in', 'IN'),
#  ('leader', 'NN'),
#  ('is', 'VBZ'),
#  ('believ', 'VBN'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('indic', 'JJ'),
#  ('of', 'IN'),
#  ('deep', 'JJ'),
#  ('divis', 'NN'),
#  ('within', 'IN'),
#  ('the', 'DT'),
#  ('govern', 'NN'),
#  ('.', '.'),
#  ('a', 'DT'),
#  ('new', 'JJ'),
#  ('report', 'NN'),
#  ('say', 'VBP'),
#  ('near', 'IN'),
#  ('4', 'CD'),
#  ('peopl', 'NNS'),
#  ('have', 'VBP'),
#  ('been', 'VBN'),
#  ('kill', 'VBN'),
#  ('in', 'IN'),
#  ('fight', 'NN'),
#  ('in', 'IN'),
#  ('afghanistan', 'NN'),
#  ('this', 'DT'),
#  ('year', 'NN'),
#  ('.', '.'),
#  ('the', 'DT'),
#  ('joint', 'JJ'),
#  ('coordin', 'NN'),
#  ('and', 'CC'),
#  ('monitor', 'NN'),
#  ('board', 'NN'),
#  ('monday', 'NN'),
#  (',', ','),
#  ('say', 'VBP'),
#  ('insurg', 'NN'),
#  ('violenc', 'NN'),
#  ('has', 'VBZ'),
#  ('kill', 'VBN'),
#  ('3700', 'CD'),
#  ('peopl', 'NN'),
#  ('so', 'RB'),
#  ('far', 'RB'),
#  ('this', 'DT'),
#  ('year', 'NN'),
#  (',', ','),
#  ('most', 'JJS'),
#  ('of', 'IN'),
#  ('them', 'PRP'),
#  ('rebel', 'NN'),
#  ('.', '.'),
#  ('the', 'DT'),
#  ('report', 'NN'),
#  ('also', 'RB'),
#  ('say', 'VBP'),
#  ('milit', 'JJ'),
#  ('launch', 'NN'),
#  ('about', 'IN'),
#  ('600', 'CD'),
#  ('attack', 'NN'),
#  ('a', 'DT'),
#  ('month', 'NN'),
#  (',', ','),
#  ('four', 'CD'),
#  ('time', 'NN'),
#  ('higher', 'JJR'),
#  ('than', 'IN'),
#  ('last', 'JJ'),
#  ('year', 'NN'),
#  ("'s", 'POS'),
#  ('month', 'NN'),
#  ('averag', 'NN'),
#  ('.', '.'),
#  ('the', 'DT'),
#  ('monitor', 'NN'),
#  ('board', 'NN'),
#  ('is', 'VBZ'),
#  ('compris', 'VBN'),
#  ('of', 'IN'),
#  ('afghan', 'NN'),
#  ('and', 'CC'),
#  ('intern', 'JJ'),
#  ('repres', 'NNS'),
#  (',', ','),
#  ('includ', 'VBP'),
#  ('the', 'DT'),
#  ('unit', 'NN'),
#  ('nation', 'NN'),
#  ('.', '.'),
#  ('the', 'DT'),
#  ('report', 'NN'),
#  ('come', 'VBD'),
#  ('as', 'IN'),
#  ('afghan', 'JJ'),
#  ('offici', 'NN'),
#  ('announc', 'NN'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('bodi', 'NN'),
#  ('of', 'IN'),
#  ('20', 'CD'),
#  ('taleban', 'JJ'),
#  ('milit', 'NN'),
#  ('had', 'VBD'),
#  ('been', 'VBN'),
#  ('recov', 'VBN'),
#  ('from', 'IN'),
#  ('bermel', 'JJ'),
#  ('district', 'NN'),
#  ('in', 'IN'),
#  ('paktika', 'JJ'),
#  ('provinc', 'NN'),
#  (',', ','),
#  ('where', 'WRB'),
#  ('nato', 'NN'),
#  ('and', 'CC'),
#  ('afghan', 'NN'),
#  ('forc', 'VBP'),
#  ('recent', 'JJ'),
#  ('conduct', 'NN'),
#  ('a', 'DT'),
#  ('mission', 'NN'),
#  ('.', '.'),
#  ('a', 'DT'),
#  ('u.s.-back', 'JJ'),
#  ('oper', 'NN'),
#  ('push', 'NN'),
#  ('the', 'DT'),
#  ('taleban', 'NN'),
#  ('from', 'IN'),
#  ('power', 'NN'),
#  ('in', 'IN'),
#  ('2001', 'CD'),
#  (',', ','),
#  ('but', 'CC'),
#  ('member', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('extremist', 'NN'),
#  ('group', 'NN'),
#  ('continu', 'NN'),
#  ('to', 'TO'),
#  ('fight', 'VB'),
#  ('afghan', 'NN'),
#  ('and', 'CC'),
#  ('foreign', 'JJ'),
#  ('forc', 'JJ'),
#  ('defend', 'VBP'),
#  ('the', 'DT'),
#  ('kabul', 'NN'),
#  ('govern', 'NN'),
#  ('.', '.'),
#  ('indian', 'JJ'),
#  ('border', 'NN'),
#  ('secur', 'NN'),
#  ('forc', 'NNS'),
#  ('are', 'VBP'),
#  ('accus', 'PDT'),
#  ('their', 'PRP$'),
#  ('pakistani', 'JJ'),
#  ('counterpart', 'NN'),
#  ('of', 'IN'),
#  ('lob', 'NN'),
#  ('at', 'IN'),
#  ('least', 'JJS'),
#  ('four', 'CD'),
#  ('rocket', 'NN'),
#  ('into', 'IN'),
#  ('northern', 'JJ'),
#  ('punjab', 'JJ'),
#  ('state', 'NN'),
#  ('.', '.'),
#  ('indian', 'JJ'),
#  ('offici', 'NN'),
#  ('said', 'VBD'),
#  ('no', 'DT'),
#  ('one', 'NN'),
#  ('was', 'VBD'),
#  ('injur', 'VBN'),
#  ('in', 'IN'),
#  ('saturday', 'NN'),
#  ("'s", 'POS'),
#  ('incid', 'NN'),
#  ('but', 'CC'),
#  ('that', 'IN'),
#  ('two', 'CD'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('rocket', 'NN'),
#  ('land', 'NN'),
#  ('near', 'IN'),
#  ('a', 'DT'),
#  ('border', 'NN'),
#  ('secur', 'NN'),
#  ('outpost', 'FW'),
#  ('.', '.'),
#  ('two', 'CD'),
#  ('more', 'JJR'),
#  ('land', 'NN'),
#  ('in', 'IN'),
#  ('field', 'NN'),
#  ('belong', 'NN'),
#  ('to', 'TO'),
#  ('a', 'DT'),
#  ('nearbi', 'JJ'),
#  ('villag', 'NN'),
#  ('.', '.'),
#  ('they', 'PRP'),
#  ('say', 'VBP'),
#  ('not', 'RB'),
#  ('all', 'DT'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('rocket', 'NN'),
#  ('explod', 'VBZ'),
#  ('upon', 'IN'),
#  ('impact', 'NN'),
#  ('.', '.'),
#  ('local', 'JJ'),
#  ('news', 'NN'),
#  ('report', 'NN'),
#  ('said', 'VBD'),
#  ('at', 'IN'),
#  ('least', 'JJS'),
#  ('five', 'CD'),
#  ('mortar', 'NN'),
#  ('shell', 'NN'),
#  ('hit', 'VBD'),
#  ('the', 'DT'),
#  ('palac', 'NN'),
#  ('compound', 'NN'),
#  ('and', 'CC'),
#  ('other', 'JJ'),
#  ('mortar', 'NN'),
#  ('were', 'VBD'),
#  ('fire', 'JJ'),
#  ('elsewher', 'NN'),
#  ('in', 'IN'),
#  ('mogadishu', 'NN'),
#  ('wednesday', 'NN'),
#  ('.', '.'),
#  ('the', 'DT'),
#  ('attack', 'NN'),
#  ('occur', 'NN'),
#  ('after', 'IN'),
#  ('the', 'DT'),
#  ('govern', 'NN'),
#  ('said', 'VBD'),
#  ('it', 'PRP'),
#  ('will', 'MD'),
#  ('go', 'VB'),
#  ('ahead', 'RB'),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('reconcili', 'NN'),
#  ('confer', 'NN'),
#  ('to', 'TO'),
#  ('which', 'WDT'),
#  ('more', 'JJR'),
#  ('than', 'IN'),
#  ('1,3', 'CD'),
#  ('somali', 'JJ'),
#  ('elder', 'NN'),
#  (',', ','),
#  ('warlord', 'NN'),
#  ('and', 'CC'),
#  ('politician', 'NN'),
#  ('are', 'VBP'),
#  ('invit', 'NN'),
#  ('.', '.'),
#  ('iraqi', 'NN'),
#  ('militari', 'NN'),
#  ('offici', 'NNS'),
#  ('say', 'VBP'),
#  ('tank', 'NN'),
#  ('and', 'CC'),
#  ('troop', 'NN'),
#  ('have', 'VBP'),
#  ('arriv', 'VBN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('northern', 'JJ'),
#  ('citi', 'NN'),
#  ('mosul', 'NN'),
#  ('for', 'IN'),
#  ('a', 'DT'),
#  ('new', 'JJ'),
#  ('offens', 'NNS'),
#  ('against', 'IN'),
#  ('al', 'NN'),
#  ('qaida', 'NN'),
#  ('in', 'IN'),
#  ('iraq', 'JJ'),
#  ('fighter', 'NN'),
#  ('.', '.'),
#  ('offici', 'NN'),
#  ('will', 'MD'),
#  ('not', 'RB'),
#  ('say', 'VB'),
#  ('how', 'WRB'),
#  ('mani', 'JJ'),
#  ('troop', 'NN'),
#  ('have', 'VBP'),
#  ('arriv', 'VBN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('sunni', 'NN'),
#  ('arab', 'NN'),
#  ('and', 'CC'),
#  ('kurdish', 'JJ'),
#  ('citi', 'NN'),
#  (',', ','),
#  ('where', 'WRB'),
#  ('bomb', 'NN'),
#  ('last', 'JJ'),
#  ('week', 'NN'),
#  ('kill', 'NN'),
#  ('at', 'IN'),
#  ('least', 'JJS'),
#  ('34', 'CD'),
#  ('peopl', 'NN'),
#  ('and', 'CC'),
#  ('wound', 'VBD'),
#  ('more', 'JJR'),
#  ('than', 'IN'),
#  ('200', 'CD'),
#  ('.', '.'),
#  ('u.s.', 'JJ'),
#  ('command', 'NN'),
#  ('have', 'VBP'),
#  ('not', 'RB'),
#  ('explain', 'VB'),
#  ('how', 'WRB'),
#  ('american', 'JJ'),
#  ('forc', 'NN'),
#  ('will', 'MD'),
#  ('particip', 'VB'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('offens', 'NNS'),
#  ('.', '.'),
#  ('offici', 'NNS'),
#  ('say', 'VBP'),
#  ('al', 'JJ'),
#  ('qaida', 'NN'),
#  ('in', 'IN'),
#  ('iraq', 'NN'),
#  ('fighter', 'NN'),
#  ('have', 'VBP'),
#  ('fled', 'VBN'),
#  ('success', 'NN'),
#  ('campaign', 'NN'),
#  ('against', 'IN'),
#  ('them', 'PRP'),
#  ('in', 'IN'),
#  ('anbar', 'NN'),
#  ('provinc', 'NN'),
#  ('and', 'CC'),
#  ('baghdad', 'NN'),
#  ('to', 'TO'),
#  ('other', 'JJ'),
#  ('northern', 'JJ'),
#  ('provinc', 'NN'),
#  ('.', '.'),
#  ('mosul', 'NN'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('largest', 'JJS'),
#  ('citi', 'JJ'),
#  ('north', 'NN'),
#  ('of', 'IN'),
#  ('baghdad', 'NN'),
#  ('and', 'CC'),
#  ('has', 'VBZ'),
#  ('long', 'RB'),
#  ('been', 'VBN'),
#  ('a', 'DT'),
#  ('stronghold', 'NN'),
#  ('of', 'IN'),
#  ('sunni', 'JJ'),
#  ('milit', 'NN'),
#  ('fighter', 'NN'),
#  ('.', '.'),
#  ('in', 'IN'),
#  ('other', 'JJ'),
#  ('violenc', 'NN'),
#  (',', ','),
#  ('u.s.', 'JJ'),
#  ('offici', 'NN'),
#  ('said', 'VBD'),
#  ('one', 'CD'),
#  ('american', 'JJ'),
#  ('soldier', 'NN'),
#  ('was', 'VBD'),
#  ('kill', 'VBN'),
#  ('while', 'IN'),
#  ('on', 'IN'),
#  ('patrol', 'NN'),
#  ('in', 'IN'),
#  ('baghdad', 'NN'),
#  ('sunday', 'NN'),
#  ('.', '.'),
#  ('egyptian', 'JJ'),
#  ('polic', 'NN'),
#  ('have', 'VBP'),
#  ('arrest', 'VBN'),
#  ('at', 'IN'),
#  ('least', 'JJS'),
#  ('16', 'CD'),
#  ('member', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('opposit', 'NN'),
#  ('muslim', 'RB'),
#  ('brotherhood', 'NN'),
#  ('as', 'IN'),
#  ('part', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('countri', 'NN'),
#  ('prepar', 'NN'),
#  ('for', 'IN'),
#  ('parliamentari', 'NN'),
#  ('runoff', 'NN'),
#  ('elect', 'NN'),
#  ('saturday', 'NN'),
#  ('.', '.'),
#  ('the', 'DT'),
#  ('arrest', 'NN'),
#  ('occur', 'NN'),
#  ('friday', 'NN'),
#  ('in', 'IN'),
#  ('alexandria', 'NN'),
#  ('.', '.'),
#  ('a', 'DT'),
#  ('spokesman', 'NN'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('brotherhood', 'NN'),
#  ('said', 'VBD'),
#  ('the', 'DT'),
#  ('arrest', 'NN'),
#  ('are', 'VBP'),
#  ('an', 'DT'),
#  ('attempt', 'NN'),
#  ('to', 'TO'),
#  ('cut', 'VB'),
#  ('the', 'DT'),
#  ('brotherhood', 'NN'),
#  ('off', 'IN'),
#  ('from', 'IN'),
#  ('it', 'PRP'),
#  ('support', 'NN'),
#  ('and', 'CC'),
#  ('punish', 'NN'),
#  ('for', 'IN'),
#  ('win', 'JJ'),
#  ('parliamentari', 'JJ'),
#  ('seat', 'NN'),
#  ('in', 'IN'),
#  ('earlier', 'JJR'),
#  ('elect', 'NN'),
#  ('.', '.'),
#  ('the', 'DT'),
#  ('muslim', 'NN'),
#  ('brotherhood', 'NN'),
#  ('has', 'VBZ'),
#  ('tripl', 'VBN'),
#  ('it', 'PRP'),
#  ('strength', 'NN'),
#  ('in', 'IN'),
#  ('parliament', 'NN'),
#  ('in', 'IN'),
#  ('recent', 'JJ'),
#  ('elect', 'NN'),
#  (',', ','),
#  ('rais', 'VB'),
#  ('the', 'DT'),
#  ('parti', 'NN'),
#  ("'s", 'POS'),
#  ('total', 'JJ'),
#  ('to', 'TO'),
#  ('47', 'CD'),
#  ('seat', 'NN'),
#  ('.', '.'),
#  ('in', 'IN'),
#  ('saturday', 'NN'),
#  ("'s", 'POS'),
#  ('elect', 'NN'),
#  (',', ','),
#  ('voter', 'NN'),
#  ('will', 'MD'),
#  ('cast', 'VB'),
#  ('ballot', 'NN'),
#  ('in', 'IN'),
#  ('nine', 'CD'),
#  ('provinc', 'NN'),
#  ('where', 'WRB'),
#  ('no', 'DT'),
#  ('candid', 'JJ'),
#  ('won', 'VBD'),
#  ('a', 'DT'),
#  ('major', 'JJ'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('previous', 'JJ'),
#  ('round', 'NN'),
#  ('of', 'IN'),
#  ('vote', 'NN'),
#  ('.', '.'),
#  ('the', 'DT'),
#  ('muslim', 'JJ'),
#  ('brotherhood', 'NN'),
#  ('is', 'VBZ'),
#  ('ban', 'JJ'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('polit', 'NN'),
#  ('parti', 'NN'),
#  (',', ','),
#  ('but', 'CC'),
#  ('it', 'PRP'),
#  ('endors', 'VBZ'),
#  ('so-cal', 'JJ'),
#  ('independ', 'NN'),
#  ('candid', 'NN'),
#  ('whose', 'WP$'),
#  ('allegi', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('parti', 'NN'),
#  ('is', 'VBZ'),
#  ('known', 'VBN'),
#  ('to', 'TO'),
#  ('voter', 'VB'),
#  ('.', '.'),
#  ('hardlin', 'NN'),
#  ('lawmak', 'NN'),
#  ('in', 'IN'),
#  ('pakistan', 'NN'),
#  ("'s", 'POS'),
#  ('north', 'JJ'),
#  ('west', 'NN'),
#  ('frontier', 'NN'),
#  ('provinc', 'NNS'),
#  ('have', 'VBP'),
#  ('push', 'VBN'),
#  ('through', 'IN'),
#  ('a', 'DT'),
#  ('law', 'NN'),
#  ('that', 'WDT'),
#  ('aim', 'VBZ'),
#  ('to', 'TO'),
#  ('ensur', 'VB'),
#  ('"', 'NNP'),
#  ('islam', 'NN'),
#  ('correct', 'NN'),
#  ('"', 'NNP'),
#  ('in', 'IN'),
#  ('public', 'JJ'),
#  ('place', 'NN'),
#  ('and', 'CC'),
#  ('establish', 'VB'),
#  ('a', 'DT'),
#  ('moral', 'JJ'),
#  ('polic', 'NN'),
#  ('to', 'TO'),
#  ('enforc', 'VB'),
#  ('decent', 'JJ'),
#  ('behavior', 'NN'),
#  ('.', '.'),
#  ('a', 'DT'),
#  ('six-parti', 'JJ'),
#  ('coalit', 'NN'),
#  ('of', 'IN'),
#  ('religi', 'JJ'),
#  ('base', 'NN'),
#  ('parti', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('mutahida', 'NN'),
#  ('majlis-e-am', 'NN'),
#  (',', ','),
#  ('domin', 'VBZ'),
#  ('the', 'DT'),
#  ('provinci', 'NN'),
#  ('assembl', 'NN'),
#  (',', ','),
#  ('so', 'IN'),
#  ('the', 'DT'),
#  ('bill', 'NN'),
#  ('was', 'VBD'),
#  ('easili', 'JJ'),
#  ('pass', 'NN'),
#  ('thursday', 'NN'),
#  ('by', 'IN'),
#  ('a', 'DT'),
#  ('vote', 'NN'),
#  ('of', 'IN'),
#  ('68-34', 'JJ'),
#  ('.', '.'),
#  ('the', 'DT'),
#  ('provinci', 'JJ'),
#  ('governor', 'NN'),
#  ('must', 'MD'),
#  ('still', 'RB'),
#  ('sign', 'VB'),
#  ('the', 'DT'),
#  ('bill', 'NN'),
#  ('befor', 'VBZ'),
#  ('it', 'PRP'),
#  ('becom', 'JJ'),
#  ('law', 'NN'),
#  (',', ','),
#  ('a', 'DT'),
#  ('step', 'NN'),
#  ('seen', 'VBN'),
#  ('onli', 'RB'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('formal', 'JJ'),
#  ('.', '.'),
#  ('the', 'DT'),
#  ('propos', 'NN'),
#  ('law', 'NN'),
#  ('call', 'NN'),
#  ('for', 'IN'),
#  ('set', 'VBN'),
#  ('up', 'RP'),
#  ('a', 'DT'),
#  ('"', 'NN'),
#  ('religi', 'NN'),
#  ('polic', 'JJ'),
#  ('forc', 'NN'),
#  ('"', 'NN'),
#  ('to', 'TO'),
#  ('make', 'VB'),
#  ('sure', 'JJ'),
#  ('peopl', 'NN'),
#  ('adher', 'NN'),
#  ('to', 'TO'),
#  ('islam', 'VB'),
#  ('valu', 'NN'),
#  ('in', 'IN'),
#  ('public', 'JJ'),
#  ('place', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('entertain', 'VBP'),
#  ('outlet', 'NN'),
#  ('close', 'JJ'),
#  ('dure', 'NN'),
#  ('week', 'NN'),
#  ('friday', 'JJ'),
#  ('prayer', 'NN'),
#  ('.', '.'),
#  ('violat', 'NN'),
#  ('could', 'MD'),
#  ('be', 'VB'),
#  ('jail', 'NN'),
#  ('for', 'IN'),
#  ('up', 'IN'),
#  ('to', 'TO'),
#  ('six', 'CD'),
#  ('month', 'NN'),
#  ('.', '.'),
#  ('the', 'DT'),
#  ('opposit', 'NN'),
#  ('has', 'VBZ'),
#  ('denounc', 'VBN'),
#  ('the', 'DT'),
#  ('measur', 'NN'),
#  (',', ','),
#  ('compar', 'NN'),
#  ('it', 'PRP'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('draconian', 'JJ'),
#  ('rule', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('former', 'JJ'),
#  ('taleban', 'NN'),
#  ('in', 'IN'),
#  ('neighbor', 'NN'),
#  ('afghanistan', 'NN'),
#  ('.', '.'),
#  ('british', 'JJ'),
#  ('polic', 'NNS'),
#  ('say', 'VBP'),
#  ('they', 'PRP'),
#  ('have', 'VBP'),
#  ('arrest', 'VBN'),
#  ('a', 'DT'),
#  ('man', 'NN'),
#  ('who', 'WP'),
#  ('dress', 'VBZ'),
#  ('as', 'IN'),
#  ('suicid', 'JJ'),
#  ('bomber', 'NN'),
#  ('at', 'IN'),
#  ('a', 'DT'),
#  ('demonstr', 'NN'),
#  ('against', 'IN'),
#  ('the', 'DT'),
#  ('public', 'NN'),
#  ('of', 'IN'),
#  ('cartoon', 'NN'),
#  ('depict', 'NN'),
#  ('islam', 'NN'),
#  ("'s", 'POS'),
#  ('prophet', 'NN'),
#  ('muhammad', 'NN'),
#  ('.', '.'),
#  ('bedfordshir', 'NN'),
#  ('polic', 'NN'),
#  ('said', 'VBD'),
#  ('tuesday', 'NN'),
#  ('that', 'IN'),
#  ('omar', 'VBD'),
#  ('khayam', 'NN'),
#  ('was', 'VBD'),
#  ('arrest', 'RB'),
#  ('in', 'IN'),
#  ('bedford', 'NN'),
#  ('for', 'IN'),
#  ('breach', 'NN'),
#  ('the', 'DT'),
#  ('condit', 'NN'),
#  ('of', 'IN'),
#  ('his', 'PRP$'),
#  ('parol', 'NN'),
#  ('.', '.'),
#  ('polic', 'NN'),
#  ('said', 'VBD'),
#  ('the', 'DT'),
#  ('british', 'JJ'),
#  ('home', 'NN'),
#  ('offic', 'NN'),
#  ('sought', 'VBD'),
#  ('an', 'DT'),
#  ('investig', 'NN'),
#  ('of', 'IN'),
#  ('khayam', 'NN'),
#  ("'s", 'POS'),
#  ('behavior', 'NN'),
#  ('after', 'IN'),
#  ('he', 'PRP'),
#  ('was', 'VBD'),
#  ('photograph', 'VBN'),
#  ('last', 'JJ'),
#  ('week', 'NN'),
#  ('at', 'IN'),
#  ('a', 'DT'),
#  ('demonstr', 'NN'),
#  ('dress', 'NN'),
#  ('in', 'IN'),
#  ('fatigu', 'NN'),
#  (',', ','),
#  ('a', 'DT'),
#  ('black', 'JJ'),
#  ('cap', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('a', 'DT'),
#  ('bulki', 'NN'),
#  ('belt', 'NN'),
#  ('.', '.'),
#  ('a', 'DT'),
#  ('home', 'NN'),
#  ('offic', 'NN'),
#  ('spokesman', 'NN'),
#  ('told', 'VBD'),
#  ('the', 'DT'),
#  ('associ', 'JJ'),
#  ('press', 'NN'),
#  ('that', 'IN'),
#  ('if', 'IN'),
#  ('the', 'DT'),
#  ('behavior', 'NN'),
#  ('of', 'IN'),
#  ('a', 'DT'),
#  ('parol', 'NN'),
#  ('offend', 'VBP'),
#  ('give', 'JJ'),
#  ...]

# %%
grammar = r"""
  NP: {<DT|JJ|NN.*>+}          # Chunk sequences of DT, JJ, NN
  PP: {<IN><NP>}               # Chunk prepositions followed by NP
  VP: {<VB.*><NP|PP|CLAUSE>+$} # Chunk verbs and their arguments
  CLAUSE: {<NP><VP>}           # Chunk NP, VP
  """

# %%
cp = nltk.RegexpParser(grammar)
cs = cp.parse(sent)
print(cs)
# Out:
# (S
#   (NP presid/NN karzai/NN)
#   thank/VBD
#   his/PRP$
#   (NP alli/NN)
#   for/IN
#   their/PRP$
#   (NP help/NN)
#   (PP in/IN (NP battl/JJ terror/NN))
#   ./.
#   (NP the/DT command/NN)
#   (PP of/IN (NP nato/NN))
#   's/POS
#   (NP afghan/NN forc/NN)
#   ,/,
#   (NP british/JJ general/JJ david/NN richard/NN)
#   ,/,
#   said/VBD
#   (NP the/DT uniti/NN)
#   (PP of/IN (NP command/NN the/DT transfer/NN brought/NN))
#   will/MD
#   enhanc/VB
#   (NP the/DT effect/NN)
#   (PP of/IN (NP the/DT overal/JJ oper/NN))
#   ./.
#   (NP refer/NN)
#   to/TO
#   (NP the/DT fight/NN)
#   (PP in/IN (NP southern/JJ afghanistan/JJ sinc/NN nato/NNS))
#   took/VBD
#   (NP command/NN)
#   there/RB
#   (PP in/IN (NP juli/NN))
#   ,/,
#   (NP richard/NN)
#   said/VBD
#   (NP the/DT nato/NN forc/NN)
#   has/VBZ
#   shown/VBN
#   it/PRP
#   resolv/VBZ
#   to/TO
#   meet/VB
#   (NP the/DT challeng/NN)
#   of/IN
#   it/PRP
#   (NP expand/DT mission/NN)
#   ./.
#   (NP richard/NN)
#   was/VBD
#   promot/VBN
#   to/TO
#   (NP four-star/JJ general/JJ hour/NN)
#   (PP befor/IN (NP the/DT command/NN chang/NN))
#   ./.
#   (NP burma/NN)
#   's/POS
#   (NP militari/NN govern/NN)
#   said/VBD
#   (NP today/NN)
#   (PP that/IN (NP ex-prim/JJ minist/NN khin/NN nyunt/NN))
#   was/VBD
#   (NP oust/JJ last/JJ month/NN)
#   becaus/VBD
#   his/PRP$
#   (NP investig/NN)
#   (PP of/IN (NP militari/NN command/NN))
#   threaten/VB
#   (NP the/DT uniti/NN)
#   (PP of/IN (NP the/DT arm/NN forc/NN))
#   ./.
#   (NP state-control/JJ newspap/NN)
#   (PP on/IN (NP sunday/JJ))
#   publish/VB
#   (NP a/DT speech/NN deliv/NN)
#   octob/IN
#   24/CD
#   (PP
#     by/IN
#     (NP
#       rule/NN
#       council/NN
#       member/NN
#       general/JJ
#       thura/NN
#       shwe/NN
#       mahn/NN))
#   ,/,
#   who/WP
#   said/VBD
#   (NP khin/JJ nyunt/NN)
#   began/VBD
#   (NP investig/JJ rival/NN offic/NN)
#   after/IN
#   be/VB
#   told/VBN
#   he/PRP
#   would/MD
#   be/VB
#   replac/VBN
#   (PP as/IN (NP militari/NN intellig/NN chief/NN))
#   ./.
#   (NP thura/NN shwe/NN mahn/NN)
#   said/VBD
#   (NP those/DT action/NN)
#   pose/VBP
#   (NP a/DT serious/JJ threat/NN)
#   to/TO
#   (NP the/DT uniti/NN)
#   (PP of/IN (NP the/DT militari/NN))
#   and/CC
#   (NP the/DT nation/NN)
#   ./.
#   he/PRP
#   also/RB
#   told/VBD
#   (NP businessmen/NNS)
#   (PP with/IN (NP connect/NN))
#   to/TO
#   khin/VB
#   (NP nyunt/NN)
#   to/TO
#   disclos/VB
#   (NP that/DT inform/NN)
#   to/TO
#   (NP the/DT rule/NN council/NN)
#   ./.
#   (NP the/DT former/JJ prime/JJ minist/NN)
#   was/VBD
#   (NP replac/JJ)
#   octob/RB
#   19/CD
#   (PP by/IN (NP hardlin/NN lieuten/JJ general/JJ soe/NN win/NN))
#   ./.
#   (NP the/DT chang/NN)
#   (PP in/IN (NP leader/NN))
#   is/VBZ
#   believ/VBN
#   to/TO
#   be/VB
#   (NP indic/JJ)
#   (PP of/IN (NP deep/JJ divis/NN))
#   (PP within/IN (NP the/DT govern/NN))
#   ./.
#   (NP a/DT new/JJ report/NN)
#   say/VBP
#   near/IN
#   4/CD
#   (NP peopl/NNS)
#   have/VBP
#   been/VBN
#   kill/VBN
#   (PP in/IN (NP fight/NN))
#   (PP in/IN (NP afghanistan/NN this/DT year/NN))
#   ./.
#   (NP the/DT joint/JJ coordin/NN)
#   and/CC
#   (NP monitor/NN board/NN monday/NN)
#   ,/,
#   say/VBP
#   (NP insurg/NN violenc/NN)
#   has/VBZ
#   kill/VBN
#   3700/CD
#   (NP peopl/NN)
#   so/RB
#   far/RB
#   (NP this/DT year/NN)
#   ,/,
#   most/JJS
#   of/IN
#   them/PRP
#   (NP rebel/NN)
#   ./.
#   (NP the/DT report/NN)
#   also/RB
#   say/VBP
#   (NP milit/JJ launch/NN)
#   about/IN
#   600/CD
#   (NP attack/NN a/DT month/NN)
#   ,/,
#   four/CD
#   (NP time/NN)
#   higher/JJR
#   (PP than/IN (NP last/JJ year/NN))
#   's/POS
#   (NP month/NN averag/NN)
#   ./.
#   (NP the/DT monitor/NN board/NN)
#   is/VBZ
#   compris/VBN
#   (PP of/IN (NP afghan/NN))
#   and/CC
#   (NP intern/JJ repres/NNS)
#   ,/,
#   includ/VBP
#   (NP the/DT unit/NN nation/NN)
#   ./.
#   (NP the/DT report/NN)
#   come/VBD
#   (PP as/IN (NP afghan/JJ offici/NN announc/NN))
#   (PP that/IN (NP the/DT bodi/NN))
#   of/IN
#   20/CD
#   (NP taleban/JJ milit/NN)
#   had/VBD
#   been/VBN
#   recov/VBN
#   (PP from/IN (NP bermel/JJ district/NN))
#   (PP in/IN (NP paktika/JJ provinc/NN))
#   ,/,
#   where/WRB
#   (NP nato/NN)
#   and/CC
#   (NP afghan/NN)
#   forc/VBP
#   (NP recent/JJ conduct/NN a/DT mission/NN)
#   ./.
#   (NP a/DT u.s.-back/JJ oper/NN push/NN the/DT taleban/NN)
#   (PP from/IN (NP power/NN))
#   in/IN
#   2001/CD
#   ,/,
#   but/CC
#   (NP member/NN)
#   (PP of/IN (NP the/DT extremist/NN group/NN continu/NN))
#   to/TO
#   fight/VB
#   (NP afghan/NN)
#   and/CC
#   (NP foreign/JJ forc/JJ)
#   defend/VBP
#   (NP the/DT kabul/NN govern/NN)
#   ./.
#   (NP indian/JJ border/NN secur/NN forc/NNS)
#   are/VBP
#   accus/PDT
#   their/PRP$
#   (NP pakistani/JJ counterpart/NN)
#   (PP of/IN (NP lob/NN))
#   at/IN
#   least/JJS
#   four/CD
#   (NP rocket/NN)
#   (PP into/IN (NP northern/JJ punjab/JJ state/NN))
#   ./.
#   (NP indian/JJ offici/NN)
#   said/VBD
#   (NP no/DT one/NN)
#   was/VBD
#   injur/VBN
#   (PP in/IN (NP saturday/NN))
#   's/POS
#   (NP incid/NN)
#   but/CC
#   that/IN
#   two/CD
#   (PP of/IN (NP the/DT rocket/NN land/NN))
#   (PP near/IN (NP a/DT border/NN secur/NN))
#   outpost/FW
#   ./.
#   two/CD
#   more/JJR
#   (NP land/NN)
#   (PP in/IN (NP field/NN belong/NN))
#   to/TO
#   (NP a/DT nearbi/JJ villag/NN)
#   ./.
#   they/PRP
#   say/VBP
#   not/RB
#   (NP all/DT)
#   (PP of/IN (NP the/DT rocket/NN))
#   explod/VBZ
#   (PP upon/IN (NP impact/NN))
#   ./.
#   (NP local/JJ news/NN report/NN)
#   said/VBD
#   at/IN
#   least/JJS
#   five/CD
#   (NP mortar/NN shell/NN)
#   hit/VBD
#   (NP the/DT palac/NN compound/NN)
#   and/CC
#   (NP other/JJ mortar/NN)
#   were/VBD
#   (NP fire/JJ elsewher/NN)
#   (PP in/IN (NP mogadishu/NN wednesday/NN))
#   ./.
#   (NP the/DT attack/NN occur/NN)
#   (PP after/IN (NP the/DT govern/NN))
#   said/VBD
#   it/PRP
#   will/MD
#   go/VB
#   ahead/RB
#   (PP with/IN (NP a/DT reconcili/NN confer/NN))
#   to/TO
#   which/WDT
#   more/JJR
#   than/IN
#   1,3/CD
#   (NP somali/JJ elder/NN)
#   ,/,
#   (NP warlord/NN)
#   and/CC
#   (NP politician/NN)
#   are/VBP
#   (NP invit/NN)
#   ./.
#   (NP iraqi/NN militari/NN offici/NNS)
#   say/VBP
#   (NP tank/NN)
#   and/CC
#   (NP troop/NN)
#   have/VBP
#   arriv/VBN
#   (PP in/IN (NP the/DT northern/JJ citi/NN mosul/NN))
#   (PP for/IN (NP a/DT new/JJ offens/NNS))
#   (PP against/IN (NP al/NN qaida/NN))
#   (PP in/IN (NP iraq/JJ fighter/NN))
#   ./.
#   (NP offici/NN)
#   will/MD
#   not/RB
#   say/VB
#   how/WRB
#   (NP mani/JJ troop/NN)
#   have/VBP
#   arriv/VBN
#   (PP in/IN (NP the/DT sunni/NN arab/NN))
#   and/CC
#   (NP kurdish/JJ citi/NN)
#   ,/,
#   where/WRB
#   (NP bomb/NN last/JJ week/NN kill/NN)
#   at/IN
#   least/JJS
#   34/CD
#   (NP peopl/NN)
#   and/CC
#   wound/VBD
#   more/JJR
#   than/IN
#   200/CD
#   ./.
#   (NP u.s./JJ command/NN)
#   have/VBP
#   not/RB
#   explain/VB
#   how/WRB
#   (NP american/JJ forc/NN)
#   will/MD
#   particip/VB
#   (PP in/IN (NP the/DT offens/NNS))
#   ./.
#   (NP offici/NNS)
#   say/VBP
#   (NP al/JJ qaida/NN)
#   (PP in/IN (NP iraq/NN fighter/NN))
#   have/VBP
#   fled/VBN
#   (NP success/NN campaign/NN)
#   against/IN
#   them/PRP
#   (PP in/IN (NP anbar/NN provinc/NN))
#   and/CC
#   (NP baghdad/NN)
#   to/TO
#   (NP other/JJ northern/JJ provinc/NN)
#   ./.
#   (NP mosul/NN)
#   is/VBZ
#   (NP the/DT)
#   largest/JJS
#   (NP citi/JJ north/NN)
#   (PP of/IN (NP baghdad/NN))
#   and/CC
#   has/VBZ
#   long/RB
#   been/VBN
#   (NP a/DT stronghold/NN)
#   (PP of/IN (NP sunni/JJ milit/NN fighter/NN))
#   ./.
#   (PP in/IN (NP other/JJ violenc/NN))
#   ,/,
#   (NP u.s./JJ offici/NN)
#   said/VBD
#   one/CD
#   (NP american/JJ soldier/NN)
#   was/VBD
#   kill/VBN
#   while/IN
#   (PP on/IN (NP patrol/NN))
#   (PP in/IN (NP baghdad/NN sunday/NN))
#   ./.
#   (NP egyptian/JJ polic/NN)
#   have/VBP
#   arrest/VBN
#   at/IN
#   least/JJS
#   16/CD
#   (NP member/NN)
#   (PP of/IN (NP the/DT opposit/NN))
#   muslim/RB
#   (NP brotherhood/NN)
#   (PP as/IN (NP part/NN))
#   (PP of/IN (NP the/DT countri/NN prepar/NN))
#   (PP for/IN (NP parliamentari/NN runoff/NN elect/NN saturday/NN))
#   ./.
#   (NP the/DT arrest/NN occur/NN friday/NN)
#   (PP in/IN (NP alexandria/NN))
#   ./.
#   (NP a/DT spokesman/NN)
#   (PP for/IN (NP the/DT brotherhood/NN))
#   said/VBD
#   (NP the/DT arrest/NN)
#   are/VBP
#   (NP an/DT attempt/NN)
#   to/TO
#   cut/VB
#   (NP the/DT brotherhood/NN)
#   off/IN
#   from/IN
#   it/PRP
#   (NP support/NN)
#   and/CC
#   (NP punish/NN)
#   (PP for/IN (NP win/JJ parliamentari/JJ seat/NN))
#   in/IN
#   earlier/JJR
#   (NP elect/NN)
#   ./.
#   (NP the/DT muslim/NN brotherhood/NN)
#   has/VBZ
#   tripl/VBN
#   it/PRP
#   (NP strength/NN)
#   (PP in/IN (NP parliament/NN))
#   (PP in/IN (NP recent/JJ elect/NN))
#   ,/,
#   rais/VB
#   (NP the/DT parti/NN)
#   's/POS
#   (NP total/JJ)
#   to/TO
#   47/CD
#   (NP seat/NN)
#   ./.
#   (PP in/IN (NP saturday/NN))
#   's/POS
#   (NP elect/NN)
#   ,/,
#   (NP voter/NN)
#   will/MD
#   cast/VB
#   (NP ballot/NN)
#   in/IN
#   nine/CD
#   (NP provinc/NN)
#   where/WRB
#   (NP no/DT candid/JJ)
#   won/VBD
#   (NP a/DT major/JJ)
#   (PP in/IN (NP the/DT previous/JJ round/NN))
#   (PP of/IN (NP vote/NN))
#   ./.
#   (NP the/DT muslim/JJ brotherhood/NN)
#   is/VBZ
#   (NP ban/JJ)
#   (PP as/IN (NP a/DT polit/NN parti/NN))
#   ,/,
#   but/CC
#   it/PRP
#   endors/VBZ
#   (NP so-cal/JJ independ/NN candid/NN)
#   whose/WP$
#   (NP allegi/NN)
#   to/TO
#   (NP the/DT parti/NN)
#   is/VBZ
#   known/VBN
#   to/TO
#   voter/VB
#   ./.
#   (NP hardlin/NN lawmak/NN)
#   (PP in/IN (NP pakistan/NN))
#   's/POS
#   (NP north/JJ west/NN frontier/NN provinc/NNS)
#   have/VBP
#   push/VBN
#   (PP through/IN (NP a/DT law/NN))
#   that/WDT
#   aim/VBZ
#   to/TO
#   ensur/VB
#   (NP "/NNP islam/NN correct/NN "/NNP)
#   (PP in/IN (NP public/JJ place/NN))
#   and/CC
#   establish/VB
#   (NP a/DT moral/JJ polic/NN)
#   to/TO
#   enforc/VB
#   (NP decent/JJ behavior/NN)
#   ./.
#   (NP a/DT six-parti/JJ coalit/NN)
#   (PP of/IN (NP religi/JJ base/NN parti/NN))
#   ,/,
#   (NP the/DT mutahida/NN majlis-e-am/NN)
#   ,/,
#   domin/VBZ
#   (NP the/DT provinci/NN assembl/NN)
#   ,/,
#   (PP so/IN (NP the/DT bill/NN))
#   was/VBD
#   (NP easili/JJ pass/NN thursday/NN)
#   (PP by/IN (NP a/DT vote/NN))
#   (PP of/IN (NP 68-34/JJ))
#   ./.
#   (NP the/DT provinci/JJ governor/NN)
#   must/MD
#   still/RB
#   sign/VB
#   (NP the/DT bill/NN)
#   befor/VBZ
#   it/PRP
#   (NP becom/JJ law/NN)
#   ,/,
#   (NP a/DT step/NN)
#   seen/VBN
#   onli/RB
#   (PP as/IN (NP a/DT formal/JJ))
#   ./.
#   (NP the/DT propos/NN law/NN call/NN)
#   for/IN
#   set/VBN
#   up/RP
#   (NP a/DT "/NN religi/NN polic/JJ forc/NN "/NN)
#   to/TO
#   make/VB
#   (NP sure/JJ peopl/NN adher/NN)
#   to/TO
#   islam/VB
#   (NP valu/NN)
#   (PP in/IN (NP public/JJ place/NN))
#   ,/,
#   and/CC
#   entertain/VBP
#   (NP outlet/NN close/JJ dure/NN week/NN friday/JJ prayer/NN)
#   ./.
#   (NP violat/NN)
#   could/MD
#   be/VB
#   (NP jail/NN)
#   for/IN
#   up/IN
#   to/TO
#   six/CD
#   (NP month/NN)
#   ./.
#   (NP the/DT opposit/NN)
#   has/VBZ
#   denounc/VBN
#   (NP the/DT measur/NN)
#   ,/,
#   (NP compar/NN)
#   it/PRP
#   to/TO
#   (NP the/DT draconian/JJ rule/NN)
#   (PP of/IN (NP the/DT former/JJ taleban/NN))
#   (PP in/IN (NP neighbor/NN afghanistan/NN))
#   ./.
#   (NP british/JJ polic/NNS)
#   say/VBP
#   they/PRP
#   have/VBP
#   arrest/VBN
#   (NP a/DT man/NN)
#   who/WP
#   dress/VBZ
#   (PP as/IN (NP suicid/JJ bomber/NN))
#   (PP at/IN (NP a/DT demonstr/NN))
#   (PP against/IN (NP the/DT public/NN))
#   (PP of/IN (NP cartoon/NN depict/NN islam/NN))
#   's/POS
#   (NP prophet/NN muhammad/NN)
#   ./.
#   (NP bedfordshir/NN polic/NN)
#   said/VBD
#   (NP tuesday/NN)
#   that/IN
#   omar/VBD
#   (NP khayam/NN)
#   was/VBD
#   arrest/RB
#   (PP in/IN (NP bedford/NN))
#   (PP for/IN (NP breach/NN the/DT condit/NN))
#   of/IN
#   his/PRP$
#   (NP parol/NN)
#   ./.
#   (NP polic/NN)
#   said/VBD
#   (NP the/DT british/JJ home/NN offic/NN)
#   sought/VBD
#   (NP an/DT investig/NN)
#   (PP of/IN (NP khayam/NN))
#   's/POS
#   (NP behavior/NN)
#   after/IN
#   he/PRP
#   was/VBD
#   photograph/VBN
#   (NP last/JJ week/NN)
#   (PP at/IN (NP a/DT demonstr/NN dress/NN))
#   (PP in/IN (NP fatigu/NN))
#   ,/,
#   (NP a/DT black/JJ cap/NN)
#   ,/,
#   and/CC
#   (NP a/DT bulki/NN belt/NN)
#   ./.
#   (NP a/DT home/NN offic/NN spokesman/NN)
#   told/VBD
#   (NP the/DT associ/JJ press/NN)
#   that/IN
#   (PP if/IN (NP the/DT behavior/NN))
#   (PP of/IN (NP a/DT parol/NN))
#   offend/VBP
#   (NP give/JJ caus/NN)
#   (PP for/IN (NP concern/NN))
#   ,/,
#   he/PRP
#   can/MD
#   be/VB
#   sent/VBN
#   back/RB
#   to/TO
#   (NP prison/NN)
#   ./.
#   (NP the/DT ap/NN)
#   also/RB
#   (NP report/NN khayam/NN)
#   has/VBZ
#   been/VBN
#   (PP on/IN (NP parol/NN))
#   (PP from/IN (NP prison/NN sinc/NN last/JJ year/NN))
#   (PP after/IN (NP serv/JJ))
#   half/PDT
#   his/PRP$
#   (NP six-year/JJ sentenc/NN)
#   (PP for/IN (NP drug/NN deal/NN))
#   ./.
#   (NP pakistani/NN offici/NNS)
#   say/VBP
#   (NP unidentifi/JJ gunmen/NNS)
#   have/VBP
#   kill/VBN
#   three/CD
#   (NP peopl/NN)
#   ,/,
#   includ/VB
#   (NP a/DT former/JJ govern/JJ minist/NN)
#   ,/,
#   (PP
#     in/IN
#     (NP
#       a/DT
#       semi-autonom/JJ
#       tribal/JJ
#       region/NN
#       border/NN
#       afghanistan/NN))
#   ./.
#   (NP the/DT offici/JJ)
#   say/VBP
#   (NP promin/JJ tribal/JJ leader/NN malik/NN)
#   faridullah/VBD
#   (NP khan/NN)
#   was/VBD
#   (NP travel/NN)
#   (PP in/IN (NP south/JJ waziristan/JJ sunday/NN))
#   when/WRB
#   his/PRP$
#   (NP vehicl/NN)
#   was/VBD
#   ambush/VBN
#   (PP in/IN (NP the/DT kani/NN wam/JJ area/NN))
#   ./.
#   his/PRP$
#   (NP driver/NN)
#   and/CC
#   (NP a/DT tribal/JJ elder/NN)
#   were/VBD
#   also/RB
#   kill/VBN
#   ./.
#   (NP no/DT one/NN)
#   has/VBZ
#   (NP claim/NN respons/NNS)
#   (PP for/IN (NP the/DT kill/NN))
#   ./.
#   (NP the/DT ambush/NN)
#   came/VBD
#   (NP a/DT day/NN)
#   (PP after/IN (NP a/DT command/NN))
#   (PP of/IN (NP pakistani/NN troop/NN))
#   said/VBD
#   (NP the/DT armi/NN)
#   has/VBZ
#   almost/RB
#   complet/VBN
#   (NP elimin/JJ milit/NN)
#   (PP in/IN (NP south/JJ waziristan/NN))
#   ./.
#   (NP the/DT area/NN)
#   becam/VBD
#   (NP a/DT refug/NN)
#   (PP for/IN (NP mani/JJ al-qaida/JJ))
#   and/CC
#   (NP taleban/JJ fighter/NN)
#   (PP after/IN (NP the/DT taleban/NN govern/NN))
#   was/VBD
#   oust/RB
#   (PP in/IN (NP afghanistan/NN))
#   in/IN
#   2001/CD
#   ./.
#   (NP a/DT senior/JJ pakistani/NN militari/NN offici/NNS)
#   say/VBP
#   (NP pakistan/JJ)
#   want/VBP
#   to/TO
#   put/VB
#   what/WP
#   he/PRP
#   call/VB
#   (NP the/DT "/NN)
#   sordid/VBD
#   (NP chapter/NN "/NN)
#   (PP of/IN (NP prolifer/NN))
#   by/IN
#   one/CD
#   of/IN
#   it/PRP
#   (NP top/JJ scientist/NN)
#   behind/IN
#   it/PRP
#   and/CC
#   build/VB
#   (NP civilian/JJ nuclear/JJ tie/NN)
#   (PP with/IN (NP the/DT unit/NN state/NN))
#   ./.
#   but/CC
#   he/PRP
#   say/VBP
#   (NP pakistan/NN)
#   is/VBZ
#   not/RB
#   (NP readi/JJ)
#   to/TO
#   make/VB
#   (NP the/DT nuclear/JJ scientist/NN)
#   ,/,
#   (NP abdul/JJ qadeer/NN khan/NN)
#   ,/,
#   (NP avail/NN)
#   (PP for/IN (NP direct/JJ question/NN))
#   over/IN
#   his/PRP$
#   (NP sale/NN)
#   (PP of/IN (NP nuclear/JJ part/NN))
#   and/CC
#   (NP secret/NN)
#   to/TO
#   (NP state/NN includ/NN iran/NN)
#   ,/,
#   (NP libya/NN)
#   and/CC
#   (NP north/JJ korea/NN)
#   ./.
#   he/PRP
#   said/VBD
#   there/EX
#   are/VBP
#   (NP reason/NN)
#   (PP of/IN (NP nation/NN sensit/NN))
#   for/IN
#   not/RB
#   make/VB
#   him/PRP
#   avail/VB
#   ./.
#   (NP the/DT pakistani/NN offici/NN)
#   was/VBD
#   give/VB
#   (NP a/DT background/NN brief/NN)
#   to/TO
#   (NP a/DT small/JJ group/NN)
#   (PP of/IN (NP report/NN))
#   (PP in/IN (NP washington/NN))
#   ./.
#   khan/VB
#   (NP admit/NN)
#   in/IN
#   2004/CD
#   that/IN
#   he/PRP
#   oper/VBZ
#   (NP a/DT worldwid/NN clandestin/NN network/NN)
#   to/TO
#   sell/VB
#   (NP nuclear/JJ technolog/NN)
#   (PP in/IN (NP the/DT black/JJ market/NN))
#   ./.
#   he/PRP
#   was/VBD
#   (NP place/NN)
#   (PP under/IN (NP hous/JJ arrest/NN))
#   (PP in/IN (NP islamabad/NN))
#   ,/,
#   but/CC
#   not/RB
#   (NP jail/JJ becaus/NN)
#   he/PRP
#   is/VBZ
#   consid/VBN
#   (NP the/DT father/NN)
#   (PP of/IN (NP pakistan/NN))
#   's/POS
#   (NP nuclear/JJ bomb/NN)
#   ./.
#   (NP u.s./JJ armi/JJ offici/NN)
#   said/VBD
#   (NP wednesday/NN)
#   that/IN
#   they/PRP
#   will/MD
#   not/RB
#   renew/VB
#   (NP a/DT controversi/JJ multi-billion/NN dollar/NN contract/NN)
#   (PP with/IN (NP the/DT halliburton/NN compani/NN))
#   to/TO
#   provid/VB
#   (NP logist/JJ support/NN)
#   to/TO
#   u.s./VB
#   (NP troop/NN)
#   (PP in/IN (NP iraq/NN))
#   and/CC
#   (NP elsewher/NN)
#   ./.
#   (NP halliburton/NN)
#   has/VBZ
#   been/VBN
#   (PP provid/IN (NP a/DT long/JJ list/NN))
#   (PP of/IN (NP servic/NN))
#   ,/,
#   (PP from/IN (NP meal/NN))
#   to/TO
#   communic/VB
#   ,/,
#   (PP for/IN (NP the/DT militari/NN))
#   (PP for/IN (NP sever/JJ year/NN))
#   ./.
#   (NP critic/NN)
#   (PP of/IN (NP halliburton/NN includ/NN auditor/NN))
#   and/CC
#   (NP congression/NN democrat/NN)
#   ./.
#   they/PRP
#   say/VBP
#   (NP the/DT compani/NN)
#   has/VBZ
#   produc/VBN
#   (NP some/DT shoddi/JJ work/NN)
#   and/CC
#   charg/VB
#   too/RB
#   (NP much/JJ money/NN)
#   ./.
#   (NP the/DT compani/NN strong/JJ)
#   deni/VBZ
#   (NP the/DT alleg/NN)
#   ./.
#   when/WRB
#   (NP the/DT huge/JJ contract/NN)
#   is/VBZ
#   put/VBN
#   out/RP
#   (PP for/IN (NP re-bid/NN))
#   ,/,
#   (NP sever/NN compani/NN)
#   will/MD
#   get/VB
#   (NP a/DT chanc/NN)
#   to/TO
#   compet/VB
#   (PP for/IN (NP portion/NN))
#   (PP of/IN (NP the/DT work/NN))
#   ./.
#   (NP repres/NNS)
#   (PP from/IN (NP the/DT asia/NN pacif/NN))
#   econom/FW
#   cooper/JJR
#   (NP busi/NN)
#   (PP advisori/IN (NP council/NN))
#   are/VBP
#   hold/VBN
#   (NP meet/NN this/DT week/NN)
#   to/TO
#   (NP final/JJ)
#   their/PRP$
#   (NP annual/JJ report/NN)
#   (PP for/IN (NP apec/JJ leader/NN))
#   who/WP
#   will/MD
#   hold/VB
#   (NP a/DT summit/NN)
#   (PP on/IN (NP septemb/JJ))
#   8/CD
#   and/CC
#   9/CD
#   ./.
#   (NP voa/NN)
#   's/POS
#   (NP nancy-amelia/JJ collin/NN report/NN)
#   (PP from/IN (NP sydney/NN))
#   ./.
#   (NP energi/NN)
#   ,/,
#   (NP secur/NN)
#   ,/,
#   (NP climat/NN chang/NN)
#   ,/,
#   (NP the/DT world/NN trade/NN organ/NN)
#   's/POS
#   (NP stall/NN negoti/NN)
#   ,/,
#   and/CC
#   invest/JJS
#   are/VBP
#   (NP all/DT)
#   expect/VBP
#   to/TO
#   be/VB
#   (PP among/IN (NP the/DT major/JJ topic/NN))
#   (PP in/IN (NP the/DT annual/JJ report/NN))
#   (PP of/IN (NP the/DT apec/NN busi/NN advisori/NN council/NN))
#   ,/,
#   known/VBN
#   (PP as/IN (NP abac/NN))
#   ./.
#   (NP tim/JJ harcourt/NN)
#   ,/,
#   (NP the/DT chief/JJ economist/NN)
#   (PP of/IN (NP the/DT australian/JJ trade/NN commiss/NN))
#   ,/,
#   say/VBP
#   (NP abac/JJ)
#   play/VBP
#   (NP an/DT import/NN role/NN)
#   (PP by/IN (NP inform/NN govern/NN))
#   where/WRB
#   there/EX
#   are/VBP
#   (NP problem/NN)
#   ./.
#   "/VB
#   (NP the/DT)
#   most/RBS
#   (NP import/JJ thing/NN the/DT busi/NN group/NN)
#   can/MD
#   do/VB
#   is/VBZ
#   to/TO
#   tell/VB
#   (NP the/DT govern/NN)
#   where/WRB
#   there/EX
#   are/VBP
#   (NP logjam/NN)
#   ,/,
#   where/WRB
#   there/EX
#   are/VBP
#   obstacl/RB
#   ,/,
#   where/WRB
#   (NP thing/NN)
#   can/MD
#   improv/VB
#   ,/,
#   (NP "/NNP harcourt/NN)
#   said/VBD
#   ./.
#   (NP "/NN i/JJ)
#   think/VBP
#   (NP actual/JJ abac/NN)
#   has/VBZ
#   play/VB
#   (NP a/DT pretti/NN good/JJ leadership/NN)
#   (PP on/IN (NP that/DT))
#   (PP in/IN (NP talk/NN))
#   (PP about/IN (NP trade/NN facilit/NN))
#   and/CC
#   (NP basic/JJ make/NN sure/JJ standard/NN)
#   are/VBP
#   (NP consist/JJ)
#   and/CC
#   (NP harmoni/JJ)
#   (PP across/IN (NP the/DT region/NN))
#   ./.
#   "/CC
#   (NP abac/JJ compris/NN)
#   up/RB
#   to/TO
#   three/CD
#   (NP member/NN)
#   (PP of/IN (NP the/DT privat/NN sector/NN))
#   (PP of/IN (NP each/DT))
#   (PP of/IN (NP the/DT))
#   21/CD
#   (NP economi/NN)
#   that/WDT
#   make/VBP
#   up/RP
#   (NP apec/NN)
#   ./.
#   it/PRP
#   meet/VBD
#   three/CD
#   (NP time/NN a/DT year/NN)
#   ./.
#   it/PRP
#   was/VBD
#   made/VBN
#   (NP a/DT perman/JJ bodi/NN)
#   in/IN
#   1995/CD
#   to/TO
#   provid/VB
#   (NP an/DT independ/NN busi/NN perspect/NN)
#   (PP within/IN (NP apec/NN))
#   ./.
#   (NP member/NN)
#   repres/VBZ
#   (NP a/DT rang/NN)
#   (PP of/IN (NP busi/NN sector/NN))
#   ,/,
#   (NP includ/JJ medium/NN)
#   and/CC
#   (NP small/JJ busi/NN)
#   ./.
#   (NP abac/NNS)
#   say/VBP
#   there/EX
#   is/VBZ
#   (NP a/DT need/NN)
#   (PP for/IN (NP busi/NN))
#   to/TO
#   improv/VB
#   (NP energi/JJ effici/NN)
#   and/CC
#   to/TO
#   encourag/VB
#   (NP conserv/JJ practic/JJ)
#   ,/,
#   and/CC
#   is/VBZ
#   (NP expect/JJ)
#   to/TO
#   includ/VB
#   (NP this/DT)
#   in/IN
#   it/PRP
#   (NP annual/JJ report/NN)
#   ./.
#   (NP harcourt/NN)
#   ,/,
#   (PP of/IN (NP the/DT australian/JJ trade/NN commiss/NN))
#   ,/,
#   say/VBP
#   (NP the/DT abac/JJ report/NN)
#   will/MD
#   also/RB
#   discuss/VB
#   (NP way/NN)
#   to/TO
#   enhanc/VB
#   (NP region/NN cooper/NN)
#   ./.
#   (NP "/NN i/NN)
#   reckon/VBP
#   they/PRP
#   ll/VBP
#   talk/VB
#   (NP a/DT littl/JJ bit/NN)
#   (PP about/IN (NP custom/NN))
#   and/CC
#   (NP quarantin/NN)
#   ,/,
#   (NP a/DT littl/JJ bit/NN)
#   about/IN
#   have/VBP
#   (NP consist/JJ secur/NN arrang/NN)
#   (PP around/IN (NP the/DT region/NN))
#   ,/,
#   (NP "/NNP harcourt/NN)
#   said/VBD
#   ./.
#   (NP "/NN)
#   and/CC
#   (NP i/NN)
#   think/VBP
#   they/PRP
#   ll/VBP
#   want/VBP
#   (NP a/DT one-stop/JJ shop/NN)
#   (PP in/IN (NP term/NN))
#   (PP of/IN (NP combin/NN secur/NN))
#   ,/,
#   (NP immigr/NN)
#   ,/,
#   (NP custom/NN)
#   ,/,
#   and/CC
#   quarantin/RB
#   (NP togeth/JJ �/NN)
#   just/RB
#   to/TO
#   make/VB
#   (NP sure/JJ)
#   it/PRP
#   's/VBZ
#   more/JJR
#   (NP streamlin/JJ)
#   and/CC
#   provid/VBZ
#   more/JJR
#   (NP certainti/NNS)
#   ./.
#   (NP "/JJ abac/NN)
#   is/VBZ
#   (NP the/DT onli/JJ non-government/JJ bodi/NN)
#   that/WDT
#   has/VBZ
#   (NP an/DT offici/JJ role/NN)
#   and/CC
#   (NP formal/JJ dialogu/NN)
#   (PP with/IN (NP the/DT leader/NN))
#   (PP of/IN (NP the/DT apec/NN economi/NN))
#   ./.
#   it/PRP
#   will/MD
#   present/VB
#   it/PRP
#   (NP annual/JJ report/NN)
#   (PP at/IN (NP the/DT apec/JJ leader/NN meet/NN))
#   (PP on/IN (NP saturday/NN))
#   ./.
#   (NP sudan/NN)
#   's/POS
#   (NP govern/JJ)
#   say/VBP
#   it/PRP
#   will/MD
#   (NP order/NN troop/NN)
#   to/TO
#   end/VB
#   (NP attack/NN immedi/NN)
#   (PP in/IN (NP darfur/NN))
#   ,/,
#   and/CC
#   is/VBZ
#   (NP ask/JJ rebel/NN)
#   to/TO
#   do/VB
#   (NP the/DT same/JJ)
#   ./.
#   (NP foreign/JJ minist/JJ mustafa/NN osman/JJ ismail/NN)
#   say/VBP
#   (NP sudanes/NNS troop/NNS)
#   will/MD
#   also/RB
#   withdraw/VB
#   to/TO
#   posit/VB
#   held/VBN
#   befor/PDT
#   (NP an/DT april/JJ cease-fir/NN)
#   ,/,
#   if/IN
#   rebel/VBN
#   (PP in/IN (NP the/DT western/JJ region/NN agre/NN))
#   to/TO
#   stop/VB
#   (NP attack/NN)
#   ./.
#   (NP mr./NN ismail/NN)
#   announc/VBZ
#   (NP the/DT decis/NN)
#   (PP after/IN (NP meet/NN))
#   (PP with/IN (NP offici/NN))
#   (PP from/IN (NP the/DT unit/NN nation/NN))
#   and/CC
#   (NP african/JJ union/NN)
#   (PP in/IN (NP khartoum/NN sunday/NN))
#   ./.
#   (PP in/IN (NP recent/JJ week/NN))
#   ,/,
#   (NP au/JJ offici/NNS)
#   say/VBP
#   (NP sudanes/NNS troop/NNS)
#   and/CC
#   (NP rebel/NN)
#   have/VBP
#   repeat/VBN
#   (PP violat/IN (NP the/DT april/NN truce/NN))
#   ./.
#   (NP saturday/NN)
#   ,/,
#   (NP the/DT head/NN)
#   (PP of/IN (NP au/JJ forc/NN))
#   (PP in/IN (NP darfur/JJ accus/NN sudanes/NNS))
#   govern/VBP
#   (NP helicopt/NN)
#   (PP of/IN (NP bomb/NN rebel/NN site/NN))
#   (PP in/IN (NP the/DT south/JJ darfur/JJ villag/NN))
#   (PP of/IN (NP labado/NN))
#   ./.
#   (NP khartoum/NNS)
#   say/VBP
#   (NP troop/NN)
#   were/VBD
#   defend/VBP
#   their/PRP$
#   (NP posit/NN)
#   (PP from/IN (NP rebel/JJ attack/NN))
#   ./.
#   (NP aid/NN worker/NN)
#   say/VBP
#   (NP some/DT relief/NN effort/NN)
#   have/VBP
#   been/VBN
#   suspend/VBN
#   (PP in/IN (NP south/JJ darfur/NNS due/JJ))
#   to/TO
#   (NP recent/JJ attack/NN)
#   ./.
#   (NP indonesian/JJ polic/NN)
#   have/VBP
#   arrest/VBN
#   three/CD
#   (NP men/NNS)
#   (PP in/IN (NP connect/NN))
#   (PP with/IN (NP the/DT octob/NN))
#   1/CD
#   (NP bali/NN bomb/NN)
#   that/WDT
#   left/VBD
#   23/CD
#   (NP peopl/NNS dead/JJ)
#   ./.
#   (NP indonesian/JJ polic/NN)
#   said/VBD
#   (PP wednesday/IN (NP the/DT men/NNS))
#   were/VBD
#   flown/VBN
#   to/TO
#   bali/VB
#   (PP from/IN (NP neighbor/NN java/NN island/NN))
#   (PP for/IN (NP question/NN))
#   (PP at/IN (NP bali/NN polic/JJ headquart/NN))
#   ./.
#   (NP australian/JJ)
#   and/CC
#   (NP french/JJ news/NN agenc/NNS)
#   say/VBP
#   at/IN
#   least/JJS
#   one/CD
#   (PP of/IN (NP the/DT men/NNS))
#   arrest/VBP
#   (/(
#   (NP cholili/NN)
#   )/)
#   was/VBD
#   (NP captur/JJ dure/NN a/DT seri/NN)
#   (PP of/IN (NP counter-terror/NN raid/NN last/JJ week/NN))
#   (PP in/IN (NP indonesia/NN))
#   ./.
#   (NP the/DT raid/JJ end/NN)
#   (PP with/IN (NP the/DT death/NN))
#   (PP
#     of/IN
#     (NP alleg/JJ extremist/NN bombmak/NN azahari/NN bin/NN husin/NN))
#   ./.
#   (NP indonesian/JJ author/NN blame/NN azahari/JJ bin/NN husin/NN)
#   (PP for/IN (NP orchestr/JJ last/JJ month/NN))
#   's/POS
#   (NP attack/NN)
#   (PP in/IN (NP bali/NN))
#   as/RB
#   well/RB
#   (PP as/IN (NP the/DT))
#   2002/CD
#   (NP bali/NN bomb/NN)
#   that/WDT
#   kill/VBZ
#   more/JJR
#   than/IN
#   200/CD
#   (NP peopl/NN)
#   ./.
#   (NP gunmen/NNS)
#   have/VBP
#   shot/VBN
#   and/CC
#   kill/VB
#   (NP a/DT roman/NN cathol/NN nun/NN)
#   and/CC
#   her/PRP$
#   (NP bodyguard/NN)
#   (PP at/IN (NP the/DT hospit/NN))
#   where/WRB
#   she/PRP
#   work/VB
#   (PP in/IN (NP islamist-control/JJ mogadishu/NN))
#   ,/,
#   (NP somalia/NN)
#   ./.
#   (NP some/DT wit/NN)
#   to/TO
#   (NP the/DT sunday/JJ shoot/NN)
#   said/VBD
#   they/PRP
#   fear/VBP
#   (NP the/DT attack/NN)
#   was/VBD
#   link/VBN
#   to/TO
#   muslim/VB
#   anger/RB
#   (PP toward/IN (NP pope/NN benedict/NN))
#   ./.
#   two/CD
#   (NP men/NNS)
#   (PP with/IN (NP pistol/NN))
#   attack/VBP
#   (NP the/DT nun/NN)
#   ,/,
#   (NP sister/NN leonella/NN sgorbati/NN)
#   ,/,
#   after/IN
#   she/PRP
#   finish/VBD
#   teach/VB
#   (NP a/DT medic/JJ school/NN class/NN)
#   (PP at/IN (NP the/DT hospit/NN))
#   (PP in/IN (NP southern/JJ mogadishu/NN))
#   ./.
#   (NP offici/NNS)
#   say/VBP
#   one/CD
#   (NP suspect/NN)
#   was/VBD
#   arrest/RB
#   ./.
#   (PP in/IN (NP rome/NN))
#   ,/,
#   (NP a/DT vatican/JJ spokesman/NN)
#   deplor/VBZ
#   (NP the/DT attack/NN)
#   and/CC
#   said/VBD
#   he/PRP
#   hope/VB
#   it/PRP
#   was/VBD
#   (NP an/DT isol/JJ event/NN)
#   ,/,
#   and/CC
#   not/RB
#   irrate/VB
#   (NP aris/NN)
#   (PP from/IN (NP comment/NN))
#   made/VBN
#   (PP by/IN (NP the/DT pope/NN))
#   which/WDT
#   anger/VBZ
#   (NP some/DT muslim/NN)
#   ./.
#   (NP author/NN)
#   (PP in/IN (NP mogadishu/NNS))
#   have/VBP
#   not/RB
#   determin/VB
#   (NP a/DT motiv/NN)
#   (PP for/IN (NP the/DT shoot/NN))
#   ./.
#   (NP the/DT pope/NN)
#   has/VBZ
#   said/VBD
#   he/PRP
#   meant/VBD
#   (NP no/DT offens/NNS)
#   to/TO
#   muslim/VB
#   when/WRB
#   he/PRP
#   quot/VBD
#   (NP a/DT)
#   14/CD
#   (NP centuri/NN byzantin/NN emperor/NN)
#   as/IN
#   say/VBP
#   (NP some/DT teach/NN)
#   (PP of/IN (NP the/DT prophet/NN muham/NN))
#   brought/VBD
#   evil/RB
#   to/TO
#   (NP the/DT world/NN)
#   ./.
#   (NP pakistani/NN forc/NN)
#   have/VBP
#   (NP target/NN)
#   milit/VBN
#   (PP in/IN (NP the/DT northwest/NN))
#   (PP for/IN (NP a/DT third/JJ day/NN))
#   ,/,
#   (NP launch/NN airstrik/NNS)
#   that/IN
#   they/PRP
#   say/VBP
#   kill/VB
#   at/IN
#   least/JJS
#   nine/CD
#   (NP suspect/JJ insurg/NN)
#   ./.
#   helicopt/VB
#   (NP gunship/NN saturday/JJ pound/NN)
#   milit/VBD
#   (NP hideout/NN)
#   (PP in/IN (NP the/DT orakzai/NN tribal/JJ region/NN))
#   ,/,
#   where/WRB
#   (NP mani/JJ taliban/NN milit/NN)
#   are/VBP
#   believ/VBN
#   to/TO
#   have/VB
#   fled/VBN
#   to/TO
#   avoid/VB
#   (NP an/DT)
#   earlier/JJR
#   (NP militari/NN offens/NNS)
#   (PP in/IN (NP nearbi/JJ south/JJ waziristan/NN))
#   ./.
#   (NP the/DT pakistani/NN militari/NN launch/NN)
#   it/PRP
#   offens/VBZ
#   (PP in/IN (NP orakzai/NN))
#   to/TO
#   hunt/VB
#   (NP taliban/JJ insurg/NN)
#   ./.
#   so/RB
#   far/RB
#   ,/,
#   near/IN
#   100/CD
#   (NP milit/NNS)
#   have/VBP
#   been/VBN
#   (NP report/NN kill/NN)
#   (PP in/IN (NP the/DT region/NN sinc/NN thursday/NN))
#   ./.
#   (PP on/IN (NP friday/NN))
#   ,/,
#   five/CD
#   soldier/JJR
#   were/VBD
#   kill/VB
#   when/WRB
#   (NP dozen/NN)
#   (PP of/IN (NP milit/NN storm/NN a/DT militari/NN checkpoint/NN))
#   (PP in/IN (NP orakzai/NN))
#   ./.
#   at/IN
#   least/JJS
#   32/CD
#   (NP suspect/JJ milit/NN)
#   were/VBD
#   kill/VBN
#   when/WRB
#   (NP troop/NN)
#   launch/VBD
#   (NP a/DT counter-attack/NN)
#   ./.
#   elsewher/CC
#   (PP in/IN (NP the/DT northwest/NN))
#   ,/,
#   (NP author/NN)
#   (PP on/IN (NP saturday/NN))
#   found/VBD
#   (NP the/DT bodi/NN)
#   of/IN
#   six/CD
#   (NP peopl/NNS)
#   who/WP
#   had/VBD
#   been/VBN
#   shot/VBN
#   (NP dead/JJ)
#   (PP in/IN (NP the/DT kurram/JJ region/NN))
#   (PP along/IN (NP the/DT afghan/JJ border/NN))
#   ./.
#   (NP the/DT)
#   six/CD
#   were/VBD
#   kidnap/VB
#   (NP a/DT few/JJ day/NN)
#   ago/RB
#   ./.
#   (NP the/DT u.s./JJ militari/NN)
#   (PP in/IN (NP afghanistan/NNS))
#   say/VBP
#   (NP coalit/JJ forc/NN)
#   kill/VB
#   14/CD
#   (NP taleban/JJ milit/NN)
#   (PP in/IN (NP separ/JJ clash/NN this/DT week/NN))
#   ./.
#   (NP the/DT militari/NN)
#   said/VBD
#   (NP saturday/JJ)
#   13/CD
#   (NP guerrilla/NN)
#   were/VBD
#   kill/VBN
#   in/IN
#   two/CD
#   (NP encount/NN)
#   (PP in/IN (NP the/DT central/JJ provinc/NN))
#   (PP of/IN (NP uruzgan/JJ))
#   ./.
#   one/CD
#   (NP afghan/NN soldier/NN)
#   was/VBD
#   kill/VBN
#   and/CC
#   four/CD
#   (NP other/JJ)
#   ,/,
#   includ/VB
#   (NP a/DT u.s./JJ soldier/NN)
#   ,/,
#   were/VBD
#   injur/VBN
#   (PP in/IN (NP the/DT fight/NN))
#   ./.
#   (NP anoth/DT milit/NN)
#   was/VBD
#   kill/VBN
#   (PP by/IN (NP u.s./JJ troop/NN))
#   (PP in/IN (NP eastern/JJ paktika/NN provinc/NN))
#   ./.
#   (NP separ/NN)
#   ,/,
#   (NP offici/NNS)
#   say/VBP
#   four/CD
#   (NP british/JJ soldier/NN)
#   (PP from/IN (NP the/DT nato-l/JJ peacekeep/JJ mission/NN))
#   were/VBD
#   (NP wound/JJ earli/NN saturday/NN)
#   (PP in/IN (NP an/DT attack/NN))
#   (PP in/IN (NP the/DT northern/JJ citi/NN))
#   (PP of/IN (NP mazar-e-sharif/NN))
#   ./.
#   it/PRP
#   was/VBD
#   not/RB
#   (NP immedi/JJ clear/JJ)
#   what/WP
#   motiv/VBZ
#   (NP the/DT attack/NN)
#   ./.
#   (NP taleban/NN rebel/NN)
#   are/VBP
#   not/RB
#   known/VBN
#   to/TO
#   oper/VB
#   (PP in/IN (NP northern/JJ afghanistan/NN))
#   and/CC
#   (NP the/DT area/NN)
#   has/VBZ
#   been/VBN
#   (NP spare/JJ)
#   much/RB
#   (PP of/IN (NP the/DT bloodsh/NN))
#   that/WDT
#   has/VBZ
#   plagu/VBN
#   (NP southern/JJ)
#   and/CC
#   (NP eastern/JJ region/NN)
#   ./.
#   (NP russian/JJ offici/NNS)
#   say/VBP
#   at/IN
#   least/JJS
#   five/CD
#   more/JJR
#   (NP peopl/NN)
#   have/VBP
#   die/VBN
#   (PP from/IN (NP a/DT wave/NN))
#   (PP of/IN (NP extrem/NN cold/NN weather/NN))
#   grip/VBD
#   (NP the/DT nation/NN)
#   ,/,
#   bring/VBG
#   (NP the/DT death/NN toll/NN)
#   to/TO
#   43/CD
#   (PP in/IN (NP the/DT past/JJ week/NN))
#   ./.
#   emerg/CC
#   (NP medic/JJ offici/NNS)
#   say/VBP
#   (NP the/DT)
#   five/CD
#   (NP victim/NN die/NN)
#   (PP in/IN (NP moscow/NN))
#   (PP from/IN (NP exposur/NN))
#   ,/,
#   and/CC
#   (NP anoth/DT)
#   19/CD
#   (NP peopl/NNS)
#   are/VBP
#   (NP hospit/JJ)
#   (PP with/IN (NP hypothermia/NN))
#   ./.
#   (NP russia/NN)
#   's/POS
#   (NP itar-tass/JJ news/NN agenc/NN)
#   quot/VBZ
#   (NP a/DT medic/JJ offici/NN)
#   as/IN
#   say/VBP
#   (NP some/DT)
#   (PP of/IN (NP the/DT victim/NN))
#   were/VBD
#   (NP intox/JJ)
#   or/CC
#   (NP homeless/NN)
#   ./.
#   (NP the/DT unusu/JJ cold/NN weather/NN)
#   is/VBZ
#   (NP affect/JJ russia/NN)
#   ,/,
#   (NP the/DT baltic/JJ state/NN)
#   (PP of/IN (NP lithuania/NN))
#   ,/,
#   (NP latvia/NN)
#   and/CC
#   (NP estonia/NN)
#   ,/,
#   and/CC
#   is/VBZ
#   move/VBN
#   (PP into/IN (NP the/DT nordic/JJ countri/NN))
#   ./.
#   (NP the/DT death/NN toll/NN)
#   is/VBZ
#   (NP expect/JJ)
#   to/TO
#   rise/VB
#   (PP as/IN (NP temperatur/NN continu/NN))
#   to/TO
#   hover/VB
#   around/IN
#   minus/$
#   30/CD
#   (NP degre/NN celsius/NN)
#   or/CC
#   lower/JJR
#   (NP overnight/NN)
#   ./.
#   (NP emerg/JJ power/NN ration/NN)
#   has/VBZ
#   been/VBN
#   put/VBN
#   (PP into/IN (NP effect/NN))
#   (PP around/IN (NP moscow/NN))
#   ./.
#   (NP health/NN offici/NN)
#   (PP in/IN (NP vietnam/NNS))
#   say/VBP
#   (NP a/DT dead/JJ strain/NN)
#   (PP of/IN (NP the/DT bird/NN flu/NN virus/NN))
#   has/VBZ
#   kill/VBN
#   (NP a/DT second/JJ vietnames/NN man/NN this/DT week/NN)
#   ,/,
#   rais/VBP
#   (NP the/DT countri/NN)
#   's/POS
#   (NP death/NN toll/NN)
#   (PP from/IN (NP the/DT virus/NN))
#   to/TO
#   50/CD
#   ./.
#   (NP offici/NNS)
#   say/VBP
#   (NP the/DT 27-year/JJ old/JJ man/NN)
#   (PP from/IN (NP vietnam/NN))
#   's/POS
#   (NP
#     northern/JJ
#     ninh/JJ
#     binh/NN
#     provinc/NN
#     die/NN
#     late/JJ
#     thursday/NN)
#   and/CC
#   (NP test/NN posit/NN)
#   (PP for/IN (NP the/DT h5n1/NN strain/NN))
#   (PP of/IN (NP bird/NN flu/NN))
#   ./.
#   (NP offici/NNS)
#   say/VBP
#   (NP the/DT man/NN)
#   fell/VBD
#   ill/RB
#   (PP after/IN (NP slaughter/NN))
#   two/CD
#   (NP chicken/NN)
#   at/IN
#   his/PRP$
#   (NP home/NN)
#   ./.
#   he/PRP
#   is/VBZ
#   (NP the/DT third/JJ person/NN)
#   to/TO
#   die/VB
#   (PP from/IN (NP avian/JJ influenza/NN))
#   (PP in/IN (NP vietnam/NN this/DT year/NN))
#   ./.
#   not/RB
#   count/VB
#   (NP the/DT)
#   latest/JJS
#   (NP death/NN)
#   ,/,
#   (NP the/DT world/NN health/NN organ/NNS)
#   say/VBP
#   227/CD
#   (NP peopl/NN)
#   (PP around/IN (NP the/DT world/NN))
#   have/VBP
#   die/VBN
#   (PP from/IN (NP bird/NN flu/NN sinc/NN))
#   2003/CD
#   ./.
#   most/JJS
#   (PP of/IN (NP the/DT world/NN))
#   's/POS
#   (NP case/NN)
#   ,/,
#   103/CD
#   ,/,
#   have/VBP
#   occur/VBN
#   (PP in/IN (NP indonesia/NN))
#   ./.
#   (NP wit/NN)
#   (PP in/IN (NP somalia/NNS))
#   say/VBP
#   (NP insurg/NNS)
#   have/VBP
#   burn/VBN
#   and/CC
#   drag/VBP
#   (NP the/DT bodi/NN)
#   of/IN
#   at/IN
#   least/JJS
#   two/CD
#   soldier/JJR
#   (PP through/IN (NP the/DT street/NN))
#   (PP of/IN (NP mogadishu/NN))
#   ,/,
#   (PP after/IN (NP a/DT clash/NN))
#   (PP between/IN (NP milit/NN))
#   and/CC
#   (NP ethiopian/JJ forc/NN)
#   kill/VB
#   seven/CD
#   (NP peopl/NNS)
#   ./.
#   (NP the/DT violenc/NN erupt/NN wednesday/NN)
#   (PP after/IN (NP insurg/JJ attack/NN ethiopian/JJ tank/NN roll/NN))
#   (PP through/IN (NP an/DT insurg/NN stronghold/NN))
#   (PP near/IN (NP the/DT headquart/NN))
#   (PP of/IN (NP the/DT former/JJ defens/NNS ministri/NN))
#   (PP in/IN (NP southern/JJ mogadishu/NN))
#   ./.
#   (NP wit/NNS)
#   say/VBP
#   (NP the/DT ethiopian/JJ troop/NN return/NN heavi/NN fire/NN)
#   and/CC
#   (PP that/IN (NP sever/NN peopl/NN))
#   were/VBD
#   wound/VBN
#   (PP in/IN (NP the/DT fight/NN))
#   ./.
#   ethiopia/CC
#   (NP deploy/JJ soldier/NN)
#   to/TO
#   somalia/VB
#   (NP last/JJ decemb/NN)
#   to/TO
#   help/VB
#   (NP
#     the/DT
#     interim/JJ
#     govern/JJ
#     push/NN
#     an/DT
#     islamist/JJ
#     movement/NN)
#   (PP from/IN (NP power/NN))
#   ./.
#   (NP somalia/NN)
#   's/POS
#   (NP internationally-recogn/JJ govern/NN)
#   has/VBZ
#   sinc/VBN
#   been/VBN
#   struggl/VBN
#   to/TO
#   contain/VB
#   (NP regular/JJ outburst/NN)
#   (PP of/IN (NP violenc/NN))
#   (PP by/IN (NP fighter/NN loyal/NN))
#   to/TO
#   (NP the/DT)
#   fallen/VBN
#   (NP islamist/JJ movement/NN)
#   ./.
#   (NP the/DT african/JJ union/NN)
#   has/VBZ
#   deploy/VBN
#   (NP troop/NN)
#   to/TO
#   somalia/VB
#   to/TO
#   replac/VB
#   (NP the/DT ethiopian/JJ forc/NN)
#   ,/,
#   which/WDT
#   addi/VBP
#   (NP ababa/NN plan/NN)
#   to/TO
#   withdraw/VB
#   ./.
#   (NP top/JJ palestinian/JJ negoti/NN ahm/NN qureia/NNS)
#   say/VBP
#   (NP isra/NN)
#   and/CC
#   (NP palestinian/JJ mediat/NN)
#   have/VBP
#   agre/VBN
#   to/TO
#   prepar/VB
#   (NP a/DT document/NN)
#   outlin/IN
#   their/PRP$
#   (NP progress/NN)
#   (PP toward/IN (NP a/DT peac/NN accord/NN))
#   ./.
#   (PP in/IN (NP remark/NN))
#   to/TO
#   report/VB
#   ,/,
#   (NP qureia/NN)
#   said/VBD
#   (NP the/DT)
#   two/CD
#   (NP side/NN)
#   (PP agre/IN (NP dure/NN recent/JJ meet/NN))
#   to/TO
#   begin/VB
#   write/VB
#   out/RP
#   their/PRP$
#   (NP posit/NN)
#   (PP on/IN (NP all/DT issu/JJ discuss/JJ dure/NN peac/NN negoti/NN))
#   ./.
#   he/PRP
#   did/VBD
#   not/RB
#   elabor/VB
#   (PP on/IN (NP whi/NN negoti/NN))
#   had/VBD
#   come/VBN
#   to/TO
#   (NP the/DT decis/NN)
#   ./.
#   (NP isra/JJ prime/JJ minist/NN ehud/NN olmert/NN)
#   and/CC
#   (NP palestinian/JJ presid/NN mahmoud/NN abba/NN)
#   resum/VBD
#   (NP u.s.-brok/JJ peac/NN talk/NN last/JJ novemb/NN)
#   ,/,
#   but/CC
#   (NP progress/NN)
#   has/VBZ
#   been/VBN
#   (NP slow/JJ)
#   ./.
#   (NP the/DT)
#   two/CD
#   (NP side/NN)
#   have/VBP
#   express/VBN
#   (NP hope/NN)
#   (PP
#     at/IN
#     (NP
#       reach/NN
#       a/DT
#       peac/JJ
#       deal/NN
#       befor/JJ
#       u.s./JJ
#       presid/NN
#       georg/NN
#       bush/NN
#       leav/NN
#       offic/JJ
#       earli/NN
#       next/JJ
#       year/NN))
#   ./.
#   but/CC
#   (NP qureia/NN)
#   said/VBD
#   (NP wednesday/NN)
#   that/IN
#   reach/VBZ
#   (NP a/DT peac/JJ agreement/NN)
#   (PP with/IN (NP israel/NN))
#   (PP befor/IN (NP mr./NN bush/NNP))
#   leav/VBZ
#   (NP offic/NN)
#   will/MD
#   take/VB
#   (NP a/DT "/JJ miracl/NN)
#   ./.
#   "/CC
#   he/PRP
#   told/VBD
#   (NP report/NN)
#   (PP in/IN (NP the/DT west/NN bank/NN))
#   that/IN
#   there/EX
#   is/VBZ
#   still/RB
#   (NP room/NN)
#   (PP for/IN (NP progress/NN))
#   (PP in/IN (NP israeli-palestinian/JJ negoti/NN))
#   ./.
#   (NP the/DT isra/JJ militari/NNS)
#   say/VBP
#   (NP major/JJ general/JJ udi/NN)
#   adam/SYM
#   -/:
#   (NP the/DT head/NN)
#   (PP of/IN (NP the/DT armi/NN))
#   's/POS
#   (NP northern/JJ command/NN)
#   -/:
#   has/VBZ
#   announc/VBN
#   his/PRP$
#   (NP resign/NN)
#   ./.
#   (NP a/DT militari/JJ statement/NN wednesday/NN)
#   ,/,
#   said/VBD
#   (NP general/JJ adam/NN)
#   has/VBZ
#   ask/VBN
#   to/TO
#   leav/VB
#   his/PRP$
#   (NP post/NN "/NN)
#   as/RB
#   soon/RB
#   (PP as/IN (NP possibl/NN))
#   ,/,
#   (NP "/NN)
#   and/CC
#   (NP the/DT chief/NN)
#   (PP of/IN (NP staff/NN))
#   has/VBZ
#   accept/VBN
#   (NP the/DT request/NN)
#   to/TO
#   begin/VB
#   (NP the/DT process/NN)
#   of/IN
#   his/PRP$
#   (NP replac/NN)
#   ./.
#   (NP adam/NN)
#   was/VBD
#   (NP wide/JJ expect/NN)
#   to/TO
#   leav/VB
#   (NP the/DT armi/NN)
#   after/IN
#   he/PRP
#   was/VBD
#   (NP push/JJ asid/NN)
#   (PP near/IN (NP the/DT end/NN))
#   (PP of/IN (NP the/DT 34-day/JJ war/NN))
#   (PP against/IN (NP hezbollah/NN guerrilla/NN))
#   (PP in/IN (NP lebanon/NN))
#   ./.
#   he/PRP
#   was/VBD
#   replac/VBN
#   (PP by/IN (NP anoth/DT general/JJ))
#   (PP as/IN (NP "/JJ coordin/NN))
#   (PP of/IN (NP oper/NN))
#   (PP in/IN (NP lebanon/NN))
#   ./.
#   "/CC
#   (NP isra/JJ media/NNS)
#   say/VBP
#   (NP adam/NN)
#   had/VBD
#   sever/VBN
#   (NP disagr/NN)
#   (PP with/IN (NP the/DT armi/NN chief/NN))
#   ,/,
#   (NP lieuten/JJ general/JJ dan/NN halutz/NN)
#   ,/,
#   (PP over/IN (NP the/DT conduct/NN))
#   (PP of/IN (NP the/DT war/NN))
#   ./.
#   (NP a/DT washington-bas/JJ research/NN institut/NNS)
#   say/VBP
#   (NP pakistan/NN)
#   is/VBZ
#   build/VB
#   (NP a/DT nuclear/JJ reactor/NN)
#   that/WDT
#   could/MD
#   produc/VB
#   (NP enough/JJ plutonium/NN)
#   for/IN
#   40/CD
#   to/TO
#   50/CD
#   (NP nuclear/JJ weapon/NN a/DT year/NN)
#   ./.
#   (NP the/DT institut/NN)
#   (PP for/IN (NP scienc/NN))
#   and/CC
#   (NP intern/JJ secur/JJ report/NN)
#   (PP that/IN (NP satellit/JJ photo/NN))
#   show/VBP
#   (NP a/DT possibl/JJ construct/NN site/NN)
#   (PP for/IN (NP a/DT))
#   larger/JJR
#   (NP nuclear/JJ reactor/NN)
#   (PP near/IN (NP the/DT small/JJ))
#   one/CD
#   (PP in/IN (NP the/DT khushab/JJ district/NN))
#   (PP of/IN (NP punjab/NN provinc/NN))
#   ./.
#   (NP the/DT report/NN)
#   say/VBP
#   such/PDT
#   (NP a/DT reactor/NN)
#   could/MD
#   produc/VB
#   over/IN
#   200/CD
#   (NP kilogram/NNS)
#   (PP of/IN (NP weapons-grad/JJ plutonium/NN))
#   ,/,
#   (NP good/JJ)
#   for/IN
#   40/CD
#   to/TO
#   50/CD
#   (NP nuclear/JJ weapon/NN a/DT year/NN)
#   ./.
#   (NP accord/NN)
#   to/TO
#   (NP some/DT media/NNS report/NN)
#   ,/,
#   (NP pakistan/NN)
#   is/VBZ
#   now/RB
#   (NP capabl/NN)
#   (PP of/IN (NP produc/NN plutonium/NN))
#   for/IN
#   just/RB
#   two/CD
#   warhead/VBP
#   (NP a/DT year/NN)
#   ./.
#   (NP pakistan/NN)
#   's/POS
#   (NP
#     foreign/JJ
#     ministri/JJ
#     spokeswoman/NN
#     tasnim/NN
#     aslam/JJ
#     declin/NN)
#   to/TO
#   say/VB
#   (PP whether/IN (NP a/DT new/JJ reactor/NN))
#   is/VBZ
#   be/VB
#   (NP construct/NN)
#   ,/,
#   but/CC
#   she/PRP
#   said/VBD
#   (NP the/DT presenc/NN)
#   (PP of/IN (NP a/DT nuclear/JJ weapon/NN program/NN))
#   and/CC
#   (NP facil/NN)
#   (PP at/IN (NP khushab/NN))
#   are/VBP
#   well/RB
#   known/VBN
#   ./.
#   (NP
#     the/DT
#     american/JJ
#     diabet/NN
#     associ/JJ
#     report/NN
#     the/DT
#     diseas/NN)
#   is/VBZ
#   (NP the/DT lead/JJ caus/NN)
#   (PP of/IN (NP new/JJ case/NN))
#   (PP of/IN (NP blind/NN))
#   (PP among/IN (NP adult/NN))
#   ./.
#   it/PRP
#   is/VBZ
#   (NP the/DT lead/JJ caus/NN)
#   (PP of/IN (NP kidney/NN failur/NN))
#   ./.
#   (NP the/DT rate/NN)
#   (PP of/IN (NP amput/NN))
#   is/VBZ
#   10/CD
#   (NP time/NN)
#   higher/JJR
#   (PP among/IN (NP those/DT))
#   who/WP
#   suffer/VBP
#   (PP from/IN (NP the/DT diseas/NNS))
#   ./.
#   (NP expert/NNS)
#   say/VBP
#   (NP those/DT)
#   who/WP
#   learn/VBP
#   how/WRB
#   to/TO
#   manag/VB
#   (NP the/DT diseas/NNS)
#   earli/VBP
#   ,/,
#   can/MD
#   live/VB
#   healthier/JJR
#   and/CC
#   more/RBR
#   (NP normal/JJ live/JJ)
#   ./.
#   (NP voa/NN)
#   's/POS
#   (NP june/NN soh/NN)
#   found/VBD
#   (NP camp/NN)
#   that/IN
#   provid/VBZ
#   (NP children/NNS)
#   (PP with/IN (NP this/DT chronic/JJ))
#   diseas/VBZ
#   (NP a/DT posit/NN approach/NN)
#   to/TO
#   live/VB
#   (PP with/IN (NP diabet/NN))
#   while/IN
#   let/VB
#   them/PRP
#   just/RB
#   be/VB
#   kid/VBN
#   ./.
#   (NP ami/JJ katz/JJ narrat/NN)
#   ./.
#   (NP cuba/NN)
#   and/CC
#   (NP panama/NN)
#   have/VBP
#   said/VBD
#   they/PRP
#   will/MD
#   restor/VB
#   (NP consular/JJ relat/NN)
#   ,/,
#   (NP month/NN)
#   (PP after/IN (NP havana/NN))
#   broke/VBD
#   (NP tie/JJ)
#   (PP with/IN (NP panama/NN citi/NN))
#   (PP for/IN (NP pardon/JJ))
#   four/CD
#   (NP men/NNS)
#   convict/VBP
#   (PP in/IN (NP connect/NN))
#   (PP with/IN (NP an/DT assassin/NN attempt/NN))
#   (PP against/IN (NP cuban/NN presid/NN fidel/NN castro/NN))
#   ./.
#   (NP the/DT countri/NN agre/NN)
#   to/TO
#   reopen/VB
#   their/PRP$
#   (NP consul/NN)
#   ,/,
#   follow/VB
#   (NP a/DT meet/NN friday/NN)
#   (PP between/IN (NP panamanian/JJ presid/NN martin/NN torrijo/NN))
#   and/CC
#   (NP cuban/JJ vice/NN presid/NN carlo/NN lage/NN)
#   ./.
#   (NP the/DT meet/NN)
#   took/VBD
#   (NP place/NN)
#   (PP on/IN (NP the/DT sidelin/NN))
#   (PP of/IN (NP the/DT ibero-american/JJ summit/NN))
#   (PP in/IN (NP san/JJ jose/NN))
#   ,/,
#   (NP costa/NN rica/NN)
#   ,/,
#   where/WRB
#   (NP head/NN)
#   (PP of/IN (NP state/NN))
#   were/VBD
#   meet/VBN
#   to/TO
#   discuss/VB
#   (NP a/DT candid/NN)
#   to/TO
#   head/VB
#   (NP the/DT organ/NN)
#   (PP of/IN (NP american/JJ state/NN))
#   and/CC
#   (NP other/JJ region/NN issu/NN)
#   ./.
#   (NP cuba/NN sever/NN tie/NN)
#   (PP with/IN (NP panama/NN))
#   (PP in/IN (NP august/NN))
#   ,/,
#   (NP hour/NN)
#   (PP after/IN (NP panamanian/JJ presid/NN mireya/NN moscoso/NN))
#   ,/,
#   in/IN
#   her/PRP$
#   (NP final/JJ day/NN)
#   (PP in/IN (NP offic/NN))
#   ,/,
#   pardon/VB
#   (NP the/DT men/NNS)
#   ,/,
#   prevent/VBP
#   their/PRP$
#   (NP extradit/NN)
#   to/TO
#   cuba/VB
#   ./.
#   they/PRP
#   were/VBD
#   (NP convict/NN)
#   (PP of/IN (NP plot/NN))
#   to/TO
#   kill/VB
#   mr./FW
#   (NP castro/JJ)
#   dure/VBP
#   (NP the/DT)
#   2000/CD
#   (NP ibero-american/JJ summit/NN)
#   (PP in/IN (NP panama/NN citi/NN))
#   ./.
#   (NP the/DT isra/NN armi/NN)
#   has/VBZ
#   kill/VBN
#   (NP a/DT palestinian/JJ youth/NN)
#   (PP in/IN (NP the/DT northern/JJ gaza/NN strip/NN))
#   and/CC
#   (NP wound/NN)
#   at/IN
#   least/JJS
#   three/CD
#   (NP other/JJ peopl/NN)
#   ./.
#   (NP the/DT armi/NNS)
#   say/VBP
#   it/PRP
#   target/VB
#   (NP a/DT man/NN)
#   who/WP
#   was/VBD
#   collect/VB
#   (NP a/DT rocket/NN launcher/NN)
#   (PP from/IN (NP an/DT area/NN use/NN))
#   to/TO
#   fire/VB
#   (NP rocket/NN)
#   (PP at/IN (NP israel/JJ recent/JJ))
#   ./.
#   (NP palestinian/JJ medic/JJ sourc/NNS)
#   say/VBP
#   (NP the/DT isra/NN strike/NN)
#   kill/VB
#   (NP a/DT teenag/NN)
#   ./.
#   (NP the/DT isra/JJ militari/NN)
#   began/VBD
#   (NP an/DT offens/NNS)
#   (PP in/IN (NP gaza/NN))
#   (PP after/IN (NP milit/NN))
#   kidnap/VBD
#   (NP an/DT isra/NN soldier/NN)
#   (PP in/IN (NP june/NN))
#   ./.
#   more/JJR
#   than/IN
#   200/CD
#   (NP palestinian/JJ)
#   have/VBP
#   been/VBN
#   kill/VBN
#   (PP in/IN (NP the/DT offens/NNS))
#   ./.
#   (PP on/IN (NP sunday/NN))
#   ,/,
#   (NP palestinian/JJ prime/JJ minist/NN ismail/NN haniyeh/NN)
#   said/VBD
#   his/PRP$
#   (NP hamas-l/JJ govern/NN)
#   will/MD
#   not/RB
#   recogn/VB
#   (NP israel/NN)
#   ./.
#   he/PRP
#   said/VBD
#   (NP an/DT arab/JJ peac/NN plan/NN)
#   (PP for/IN (NP the/DT region/NN))
#   is/VBZ
#   (NP problemat/JJ)
#   becaus/IN
#   it/PRP
#   requir/VBZ
#   (NP palestinian/JJ)
#   to/TO
#   recogn/VB
#   (NP israel/NN)
#   (PP in/IN (NP exchang/NN))
#   (PP for/IN (NP an/DT isra/NN pullout/NN))
#   (PP from/IN (NP palestinian/JJ territori/NN))
#   ./.
#   he/PRP
#   spoke/VBD
#   (PP after/IN (NP a/DT week/NN))
#   (PP of/IN (NP dead/JJ polit/NN infight/NN))
#   (PP between/IN (NP hama/NN))
#   and/CC
#   (NP the/DT rival/JJ fatah/NN parti/NN)
#   (PP of/IN (NP presid/NN mahmoud/NN abba/NN))
#   ./.
#   (NP u.s./JJ automak/JJ chrysler/NN)
#   has/VBZ
#   open/VB
#   (NP a/DT)
#   $/$
#   570/CD
#   million/CD
#   (NP engin/NN plant/NN)
#   (PP in/IN (NP northern/JJ mexico/NN))
#   ./.
#   dure/VB
#   (NP the/DT ceremoni/NN startup/NN)
#   (PP of/IN (NP the/DT saltillo/NN plant/NN friday/NN))
#   ,/,
#   (NP mexican/JJ presid/NN felip/NN calderon/NN)
#   said/VBD
#   (NP chrysler/NN)
#   's/POS
#   (NP sixth/JJ plant/NN)
#   (PP in/IN (NP mexico/NN))
#   will/MD
#   creat/VB
#   700/CD
#   (NP job/NN)
#   ./.
#   (NP mr./NN calderon/NN)
#   said/VBD
#   (NP mexico/NN)
#   has/VBZ
#   becom/VBN
#   (NP a/DT worldwid/JJ leader/NN)
#   (PP in/IN (NP the/DT auto/NN industri/NN))
#   ./.
#   (NP chrysler/NN plan/NN)
#   to/TO
#   build/VB
#   it/PRP
#   (NP new/JJ fuel-effici/JJ pentastar/NN v-6/JJ engin/NN)
#   (PP for/IN (NP chrysler/NN))
#   ,/,
#   (NP dodg/NN)
#   ,/,
#   (NP jeep/NN)
#   and/CC
#   (NP ram/NN vehicl/NN)
#   ./.
#   (NP mexican/JJ offici/NNS)
#   say/VBP
#   (NP the/DT new/JJ plant/NN)
#   will/MD
#   have/VB
#   (NP the/DT capac/NN)
#   to/TO
#   build/VB
#   4,40,000/CD
#   (NP engin/NN)
#   (PP per/IN (NP year/NN))
#   ./.
#   (NP a/DT u.s./JJ juri/NN)
#   has/VBZ
#   found/VBN
#   (PP that/IN (NP drug/NN maker/NN merck/NN))
#   is/VBZ
#   not/RB
#   (NP liabl/JJ)
#   (PP for/IN (NP the/DT heart/NN attack/NN suffer/NN))
#   (PP by/IN (NP a/DT man/NN))
#   take/VB
#   it/PRP
#   (NP painkil/JJ vioxx/NN)
#   ./.
#   (NP the/DT new/JJ jersey/NN jurist/NN agre/NN)
#   (PP with/IN (NP merck/NN))
#   that/WDT
#   (NP job/NN stress/NN)
#   and/CC
#   (NP health/NN risk/NN)
#   caus/VBP
#   (NP the/DT 60-year/JJ old/JJ postal/JJ worker/NN)
#   to/TO
#   have/VB
#   (NP a/DT heart/NN attack/NN)
#   four/CD
#   (NP year/NN)
#   ago/RB
#   ./.
#   (NP the/DT plaintiff/NN argu/NN vioxx/NN)
#   was/VBD
#   (NP respons/NNS)
#   ./.
#   (NP the/DT juri/NN)
#   also/RB
#   reject/VBP
#   (NP the/DT man/NN)
#   's/POS
#   (NP claim/NN)
#   (PP that/IN (NP merck/NN))
#   fail/VBP
#   to/TO
#   proper/VB
#   warn/WP
#   (NP user/NN)
#   (PP about/IN (NP the/DT drug/NN))
#   's/POS
#   (NP risk/NN)
#   ./.
#   (NP merck/NN)
#   withdrew/VBD
#   (NP the/DT popular/JJ drug/NN last/JJ year/NN)
#   (PP after/IN (NP a/DT studi/NN show/NN))
#   it/PRP
#   doubl/VBZ
#   (NP the/DT risk/NN)
#   (PP of/IN (NP heart/NN problem/NN))
#   (PP in/IN (NP long-term/JJ user/NN))
#   ./.
#   (NP merck/NN)
#   is/VBZ
#   (NP face/JJ thousand/NN)
#   (PP of/IN (NP other/JJ lawsuit/NN))
#   (PP over/IN (NP vioxx/NN))
#   ./.
#   (NP thursday/NN)
#   's/POS
#   (NP verdict/NN)
#   is/VBZ
#   (PP onli/IN (NP the/DT second/JJ))
#   (PP in/IN (NP a/DT vioxx/JJ case/NN))
#   ./.
#   (PP in/IN (NP the/DT first/JJ))
#   ,/,
#   (NP merck/NN)
#   was/VBD
#   (NP order/NN)
#   to/TO
#   pay/VB
#   million/CD
#   (PP of/IN (NP dollar/NN))
#   to/TO
#   (NP the/DT widow/NN)
#   (PP of/IN (NP a/DT vioxx/JJ user/NN))
#   ./.
#   (NP merck/NN)
#   is/VBZ
#   (NP appeal/JJ)
#   (PP that/IN (NP decis/NN))
#   ./.
#   (NP the/DT rumor/NN)
#   are/VBP
#   (NP true/JJ)
#   :/:
#   (NP nicol/NN ritchi/NN)
#   is/VBZ
#   (NP pregnant/JJ)
#   ./.
#   (NP speak/NN)
#   to/TO
#   abc/VB
#   (NP news/NN interview/NN diann/NN sawyer/NN)
#   ,/,
#   (NP the/DT 25-year-old/JJ co-star/NN)
#   (PP of/IN (NP tv/NN))
#   's/POS
#   (NP the/DT simpl/JJ life/NN)
#   said/VBD
#   she/PRP
#   is/VBZ
#   almost/RB
#   four/CD
#   (NP month/NN)
#   along/RB
#   in/IN
#   her/PRP$
#   (NP pregnanc/NN)
#   ./.
#   she/PRP
#   said/VBD
#   (NP the/DT father/NN)
#   is/VBZ
#   her/PRP$
#   (NP boyfriend/NN)
#   ,/,
#   (NP joel/JJ madden/NN)
#   (PP of/IN (NP the/DT rock/NN band/NN good/JJ charlott/NN))
#   ./.
#   (NP ritchi/NN)
#   also/RB
#   spoke/VBD
#   about/IN
#   her/PRP$
#   (NP guilti/NN plea/NN last/JJ week/NN)
#   to/TO
#   drive/VB
#   (PP under/IN (NP the/DT influenc/NN))
#   and/CC
#   (NP the/DT result/NN four-day/JJ jail/NN sentenc/NN)
#   ./.
#   (NP "/NN i/NN)
#   have/VBP
#   (NP a/DT respons/NNS)
#   and/CC
#   it/PRP
#   's/VBZ
#   (NP someth/JJ)
#   (PP that/IN (NP i/NN))
#   did/VBD
#   (NP wrong/JJ)
#   ,/,
#   and/CC
#   (PP if/IN (NP i/NNS))
#   could/MD
#   (NP person/NN)
#   apolog/VB
#   to/TO
#   everi/VB
#   (NP singl/JJ person/NN)
#   that/WDT
#   has/VBZ
#   lost/VBN
#   (NP a/DT love/NN)
#   one/CD
#   (PP from/IN (NP drunk/NN drive/NN))
#   ,/,
#   (NP i/NN)
#   would/MD
#   ,/,
#   "/VB
#   she/PRP
#   said/VBD
#   ./.
#   (NP "/NN)
#   and/CC
#   (NP unfortun/NN i/NN)
#   ca/MD
#   n't/RB
#   ,/,
#   but/CC
#   (NP this/DT)
#   is/VBZ
#   my/PRP$
#   (NP way/NN)
#   (PP of/IN (NP pay/NN))
#   my/PRP$
#   (NP due/JJ)
#   and/CC
#   take/VB
#   (NP respons/NNS)
#   and/CC
#   be/VB
#   (NP an/DT adult/NN)
#   ./.
#   "/VB
#   (NP the/DT interview/NN air/NN)
#   august/VBP
#   2/CD
#   and/CC
#   3/CD
#   (PP on/IN (NP good/JJ morn/NN america/NN))
#   ,/,
#   and/CC
#   later/RB
#   august/RB
#   3/CD
#   on/IN
#   20/20/CD
#   ./.
#   (NP u.s./JJ senat/NN john/NN warner/NN)
#   (PP of/IN (NP the/DT southeastern/JJ state/NN))
#   (PP of/IN (NP virginia/NN))
#   ,/,
#   (NP a/DT promin/JJ republican/JJ figur/NN)
#   (PP in/IN (NP the/DT debat/NN))
#   (PP over/IN (NP the/DT war/NN))
#   (PP in/IN (NP iraq/NN))
#   ,/,
#   say/VBP
#   he/PRP
#   will/MD
#   retir/VB
#   (PP after/IN (NP finish/JJ))
#   his/PRP$
#   (NP term/NN)
#   in/IN
#   2009/CD
#   ./.
#   (NP warner/NN)
#   told/VBD
#   (NP support/NN outsid/NN)
#   (PP of/IN (NP the/DT univers/NNS))
#   (PP of/IN (NP virginia/NN friday/NN))
#   that/IN
#   he/PRP
#   will/MD
#   not/RB
#   seek/VB
#   (NP a/DT sixth/JJ term/NN)
#   (PP in/IN (NP the/DT))
#   2008/CD
#   (NP elect/NN)
#   ./.
#   (NP the/DT former/JJ chairman/NN)
#   (PP
#     of/IN
#     (NP the/DT power/NN senat/NN arm/NN servic/NN committe/NN))
#   has/VBZ
#   (NP open/JJ critic/NN presid/NN bush/NN)
#   's/POS
#   (NP handl/NN)
#   (PP of/IN (NP the/DT war/NN))
#   (PP in/IN (NP iraq/NN))
#   ./.
#   he/PRP
#   call/VB
#   (PP on/IN (NP mr./NN bush/NN))
#   earlier/RBR
# ...
#   (PP of/IN (NP the/DT open/JJ world/NN cup/NN match/NN))
#   (PP between/IN (NP host/NN south/NN africa/NN))
#   and/CC
#   (NP mexico/NN)
#   ./.
#   yonhap/CC
#   (NP
#     news/NN
#     agenc/NN
#     quot/NN
#     south/JJ
#     korean/JJ
#     broadcast/NN
#     sbs/NN)
#   as/IN
#   say/VBP
#   (NP the/DT north/JJ korean/JJ central/JJ broadcast/NN servic/NN)
#   show/VB
#   (NP a/DT record/NN)
#   (PP of/IN (NP friday/NN))
#   's/POS
#   (NP game/NN)
#   ,/,
#   despit/VB
#   it/PRP
#   lack/JJR
#   (PP of/IN (NP broadcast/NN right/NN))
#   ./.
#   (NP an/DT offici/NN)
#   is/VBZ
#   (NP quot/JJ)
#   (PP as/IN (NP say/NN sbs/NN))
#   has/VBZ
#   (NP world/NN cup/NN broadcast/NN right/NN)
#   (PP for/IN (NP the/DT whole/JJ korean/JJ peninsula/NN))
#   ./.
#   (NP the/DT offici/NN)
#   said/VBD
#   (NP sbs/NN)
#   will/MD
#   decid/VB
#   (PP on/IN (NP measur/NN))
#   (PP after/IN (NP determin/JJ))
#   how/WRB
#   (NP north/JJ korea/NN)
#   obtain/VB
#   (NP the/DT footag/NN)
#   ./.
#   (NP meanwhil/NN)
#   ,/,
#   (NP south/JJ korean/JJ nationwid/NN)
#   celebr/VBD
#   (NP the/DT victori/NN)
#   of/IN
#   their/PRP$
#   (NP team/NN)
#   in/IN
#   their/PRP$
#   (NP open/JJ world/NN cup/NN game/NN)
#   (PP against/IN (NP greec/NN))
#   ./.
#   (NP despit/NN raini/NN weather/NN)
#   ,/,
#   (NP fan/NN crowd/NN park/NN)
#   ,/,
#   (NP squar/NN)
#   and/CC
#   (NP stadium/NN)
#   (PP across/IN (NP the/DT countri/NN))
#   to/TO
#   watch/VB
#   (NP the/DT game/NN)
#   (PP on/IN (NP giant/JJ screen/NN))
#   and/CC
#   celebr/VB
#   their/PRP$
#   (NP team/NN)
#   's/POS
#   (/(
#   (NP 2-0/JJ)
#   )/)
#   (NP win/NN)
#   ./.
#   (NP cuba/NN)
#   's/POS
#   (NP health/NN ministri/NNS)
#   say/VBP
#   (NP u.s./JJ filmmak/NN michael/NN moor/NN)
#   's/POS
#   (NP new/JJ movi/NN)
#   ,/,
#   (NP "/NNP sicko/NN)
#   ,/,
#   (NP "/NNP)
#   will/MD
#   be/VB
#   (NP good/JJ public/NN)
#   (PP for/IN (NP the/DT cuban/NN health/NN care/NN system/NN))
#   ./.
#   (NP health/NN minist/NN jose/NN ramon/NN balagu/NN)
#   told/VBD
#   (NP report/NN)
#   (PP in/IN (NP havana/JJ friday/NN))
#   (PP that/IN (NP moor/NN))
#   's/POS
#   (NP movi/NN)
#   ,/,
#   (NP screen/JJ recent/JJ)
#   (PP at/IN (NP the/DT cann/NN film/NN festiv/NN))
#   ,/,
#   will/MD
#   show/VB
#   (NP the/DT world/NN the/DT human/NN)
#   (PP of/IN (NP the/DT cuban/NN health/NN care/NN system/NN))
#   ./.
#   (NP moor/NN)
#   's/POS
#   (NP documentari/NN)
#   ,/,
#   (NP schedul/NN)
#   (PP for/IN (NP u.s./JJ releas/NNS))
#   june/VBP
#   29/CD
#   ,/,
#   is/VBZ
#   (PP about/IN (NP problem/NN))
#   (PP in/IN (NP the/DT u.s./JJ health/NN care/NN system/NN))
#   ./.
#   in/IN
#   it/PRP
#   ,/,
#   (NP moor/NNS)
#   take/VBP
#   three/CD
#   (NP rescu/NNS worker/NN)
#   (PP from/IN (NP the/DT septemb/NN))
#   11th/CD
#   ,/,
#   2001/CD
#   (NP terrorist/JJ attack/NN)
#   to/TO
#   cuba/VB
#   (PP for/IN (NP health/NN care/NN))
#   ,/,
#   while/IN
#   accus/PDT
#   (NP the/DT unit/NN state/NN)
#   (PP of/IN (NP fail/NN))
#   to/TO
#   respond/VB
#   to/TO
#   their/PRP$
#   (NP need/NN)
#   ./.
#   (NP cuba/NN)
#   's/POS
#   (NP univers/NNS health/NN care/NN)
#   ,/,
#   (NP the/DT product/NN)
#   (PP of/IN (NP a/DT communist/NN govern/NN))
#   ,/,
#   is/VBZ
#   (NP consid/JJ compar/NN)
#   to/TO
#   (NP those/DT)
#   (PP of/IN (NP much/JJ))
#   wealthier/JJR
#   (NP nation/NN)
#   ./.
#   (NP moor/NN)
#   is/VBZ
#   (PP under/IN (NP investig/NN))
#   (PP by/IN (NP the/DT u.s./JJ govern/NN))
#   (PP for/IN (NP possibl/JJ violat/NN))
#   (PP of/IN (NP the/DT u.s./JJ trade/NN embargo/NN))
#   (PP on/IN (NP cuba/NN))
#   ./.
#   (NP presid/NN bush/NN)
#   has/VBZ
#   call/VBN
#   (PP for/IN (NP a/DT diplomat/NN solut/NN))
#   to/TO
#   (NP the/DT iran/NN nuclear/JJ crisi/NN)
#   ./.
#   (PP at/IN (NP the/DT white/JJ hous/JJ friday/NN))
#   ,/,
#   (NP mr./NN bush/NN)
#   said/VBD
#   (NP iran/NN)
#   must/MD
#   not/RB
#   be/VB
#   (NP allow/JJ)
#   to/TO
#   possess/VB
#   (NP a/DT nuclear/JJ weapon/NN)
#   ./.
#   he/PRP
#   said/VBD
#   it/PRP
#   is/VBZ
#   (NP logic/JJ)
#   (PP that/IN (NP a/DT countri/NN))
#   that/WDT
#   has/VBZ
#   (NP reject/JJ diplomat/NN option/NN)
#   would/MD
#   be/VB
#   refer/VBN
#   to/TO
#   (NP the/DT unit/NN nation/NN secur/NN council/NN)
#   ./.
#   (NP mr./NN bush/NN)
#   made/VBD
#   (NP those/DT comment/NN)
#   (PP after/IN (NP talk/NN))
#   (PP with/IN (NP german/JJ chancellor/NN angela/NN merkel/NN))
#   ,/,
#   who/WP
#   said/VBD
#   (NP the/DT intern/JJ communiti/NN)
#   should/MD
#   not/RB
#   be/VB
#   intimid/VBN
#   (PP by/IN (NP iran/NN))
#   ./.
#   (NP iran/NN)
#   has/VBZ
#   threaten/VBN
#   to/TO
#   end/VB
#   (NP cooper/NN)
#   (PP with/IN (NP the/DT unit/NN nation/NN nuclear/JJ agenc/NN))
#   (PP if/IN (NP tehran/NN))
#   's/POS
#   (NP nuclear/JJ program/NN)
#   is/VBZ
#   taken/VBN
#   to/TO
#   (NP the/DT secur/NN council/NN)
#   (PP for/IN (NP possibl/JJ sanction/NN))
#   ./.
#   (NP iran/NN)
#   announc/RB
#   earlier/RBR
#   (NP this/DT week/NN)
#   it/PRP
#   was/VBD
#   (NP resum/JJ nuclear/JJ fuel/NN research/NN)
#   ./.
#   (NP china/NN)
#   's/POS
#   (NP u.n./JJ ambassador/NN)
#   said/VBD
#   (NP today/NN)
#   that/WDT
#   refer/VBP
#   (NP the/DT matter/NN)
#   to/TO
#   (NP the/DT unit/NN nation/NN)
#   might/MD
#   complic/VB
#   (NP the/DT issu/NN)
#   ./.
#   (NP russia/NN)
#   has/VBZ
#   (NP urg/JJ iran/NN)
#   to/TO
#   resum/VB
#   it/PRP
#   moratorium/VB
#   (PP on/IN (NP nuclear/JJ activ/NN))
#   and/CC
#   (NP cooper/NN)
#   (PP with/IN (NP the/DT u.n./JJ nuclear/JJ agenc/NN))
#   ./.
#   (NP russia/NN)
#   has/VBZ
#   (NP urg/JJ iran/NN)
#   to/TO
#   heed/VB
#   (NP a/DT u.n./JJ secur/NN council/NN)
#   resolut/VBP
#   give/VB
#   (NP tehran/NN)
#   (PP until/IN (NP the/DT end/NN))
#   (PP of/IN (NP the/DT month/NN))
#   to/TO
#   suspend/VB
#   it/PRP
#   (NP sensit/JJ nuclear/JJ activ/NN)
#   ./.
#   (PP in/IN (NP a/DT statement/NN thursday/NN))
#   ,/,
#   (NP russia/NN)
#   's/POS
#   (NP foreign/JJ ministri/NN)
#   said/VBD
#   (NP no/DT further/JJ measur/NN)
#   (PP by/IN (NP the/DT secur/NN council/NN))
#   will/MD
#   be/VB
#   (NP requir/JJ)
#   (PP if/IN (NP iran/JJ))
#   heed/VBD
#   (NP the/DT call/NN)
#   ./.
#   (NP russia/NN)
#   ,/,
#   (NP a/DT perman/NN secur/NN council/NN member/NN)
#   ,/,
#   has/VBZ
#   (NP resist/JJ western/JJ effort/NN)
#   to/TO
#   sanction/VB
#   (NP iran/NN)
#   for/IN
#   it/PRP
#   refus/VBZ
#   to/TO
#   compli/VB
#   (PP with/IN (NP nuclear/JJ demand/NN))
#   ./.
#   (NP the/DT u.n./JJ resolut/NN)
#   ,/,
#   (NP pass/NN)
#   earlier/RBR
#   (NP this/DT week/NN)
#   ,/,
#   (NP demand/NN iran/NN)
#   stop/VB
#   (NP enrich/JJ uranium/NN)
#   (PP by/IN (NP august/JJ))
#   31st/CD
#   or/CC
#   (NP face/NN possibl/JJ sanction/NN)
#   ./.
#   (NP the/DT secur/JJ council/NN act/NN)
#   (PP after/IN (NP iran/JJ fail/NN))
#   to/TO
#   respond/VB
#   to/TO
#   (NP an/DT intern/JJ incent/NN packag/NN tehran/NN)
#   would/MD
#   get/VB
#   (PP by/IN (NP suspend/NN enrich/NN activ/NN))
#   ./.
#   (NP iranian/JJ presid/NN mahmoud/NN ahmadinejad/NN)
#   said/VBD
#   (NP thursday/JJ iran/NN)
#   is/VBZ
#   still/RB
#   consid/VB
#   (NP the/DT incent/NN packag/NN)
#   ./.
#   (NP the/DT unit/NN state/NN)
#   and/CC
#   it/PRP
#   (NP western/JJ alli/JJ believ/NN iran/NN)
#   is/VBZ
#   (NP tri/JJ)
#   to/TO
#   develop/VB
#   (NP nuclear/JJ weapon/NN)
#   ./.
#   (NP tehran/NNS)
#   say/VBP
#   it/PRP
#   (NP nuclear/JJ program/NN)
#   is/VBZ
#   (NP onli/JJ)
#   (PP for/IN (NP peac/JJ purpos/NN))
#   ./.
#   (NP indian/JJ prime/JJ minist/NN manmohan/NN)
#   singh/VBD
#   begin/VB
#   (NP a/DT two-day/JJ visit/NN)
#   to/TO
#   afghanistan/VB
#   (PP on/IN (NP sunday/NN))
#   ,/,
#   (NP the/DT first/JJ)
#   (PP by/IN (NP an/DT indian/JJ premier/NN))
#   (PP in/IN (NP near/JJ))
#   three/CD
#   (NP decad/NN)
#   ./.
#   (NP besid/NN hold/JJ talk/NN)
#   (PP with/IN (NP afghan/JJ presid/NN hamid/NN karzai/NN))
#   and/CC
#   (NP foreign/JJ minist/NN abdullah/NN)
#   ,/,
#   (NP mr./NN singh/NN)
#   is/VBZ
#   (NP schedul/JJ)
#   to/TO
#   take/VB
#   (NP part/NN)
#   (PP in/IN (NP a/DT groundbreak/NN ceremoni/NN))
#   (PP for/IN (NP a/DT new/JJ afghan/NN parliament/NN build/NN))
#   be/VB
#   built/VBN
#   (PP with/IN (NP indian/JJ help/NN))
#   ./.
#   (NP india/NN)
#   is/VBZ
#   also/RB
#   (NP involv/JJ)
#   (PP in/IN (NP train/NN afghan/NN arm/NN forc/NN))
#   and/CC
#   (NP polic/NN)
#   ,/,
#   build/VB
#   (NP road/NN)
#   ,/,
#   (NP school/NN)
#   ,/,
#   (NP hospit/NN)
#   ,/,
#   (NP power/NN line/NN)
#   ,/,
#   (NP dig/NN)
#   well/RB
#   and/CC
#   support/VB
#   (NP trade/NN)
#   and/CC
#   (NP servic/NN)
#   ./.
#   (NP wednesday/NN)
#   ,/,
#   (NP the/DT)
#   two/CD
#   countri/VBP
#   (NP sign/NN a/DT memorandum/NN)
#   (PP of/IN (NP understand/NN))
#   under/IN
#   which/WDT
#   (NP india/NN)
#   will/MD
#   upgrad/VB
#   (NP all/DT radio/NN)
#   and/CC
#   (NP televis/JJ station/NN)
#   (PP in/IN (NP afghanistan/NN))
#   ./.
#   (PP although/IN (NP india/NN))
#   and/CC
#   (NP afghanistan/JJ share/NN close/JJ histor/NN)
#   and/CC
#   (NP cultur/NN link/NN)
#   ,/,
#   (NP the/DT turmoil/NN)
#   (PP in/IN (NP the/DT central/JJ asian/JJ nation/NN))
#   had/VBD
#   not/RB
#   allow/VB
#   (NP an/DT indian/JJ prime/JJ minist/NN)
#   to/TO
#   visit/VB
#   (NP kabul/NNP)
#   sinc/VB
#   (NP a/DT trip/NN)
#   in/IN
#   1976/CD
#   (PP by/IN (NP indira/JJ gandhi/NN))
#   ./.
#   (NP nation/NN basketbal/JJ associ/NN center/NN yao/NN ming/NN)
#   is/VBZ
#   (NP rais/JJ money/NN)
#   (PP for/IN (NP victim/NN))
#   (PP of/IN (NP the/DT))
#   may/MD
#   12/CD
#   (NP earthquak/NN)
#   in/IN
#   his/PRP$
#   (NP nativ/JJ china/NN)
#   ,/,
#   by/IN
#   hold/VB
#   (NP a/DT raffl/NN)
#   (PP for/IN (NP a/DT trip/NN))
#   to/TO
#   (NP the/DT beij/NN olymp/JJ next/JJ month/NN)
#   ./.
#   (NP ticket/NN)
#   (PP for/IN (NP the/DT raffl/NN cost/NN))
#   $/$
#   2/CD
#   (/(
#   us/PRP
#   )/)
#   and/CC
#   can/MD
#   be/VB
#   purchas/VBN
#   (PP with/IN (NP a/DT credit/NN card/NN))
#   (PP on/IN (NP a/DT special/JJ internet/NN site/NN))
#   (/(
#   (NP
#     https://www.celebritiesforcharity.org/raffles/netraffle_main.cfm/NN)
#   )/)
#   ./.
#   (NP the/DT winner/NN)
#   will/MD
#   be/VB
#   (NP announc/JJ juli/NN)
#   21/CD
#   ,/,
#   and/CC
#   will/MD
#   receiv/VB
#   (NP round-trip/JJ airfar/NN)
#   (PP from/IN (NP a/DT u.s./JJ citi/NN))
#   to/TO
#   beij/VB
#   ,/,
#   (NP a/DT seven-day/JJ hotel/NN stay/NN)
#   (PP in/IN (NP beij/NN))
#   ,/,
#   two/CD
#   (NP ticket/NN)
#   to/TO
#   (NP the/DT china-usa/JJ basketbal/JJ game/NN)
#   ,/,
#   $/$
#   1500/CD
#   (NP dollar/NN)
#   (PP in/IN (NP cash/NN))
#   ,/,
#   and/CC
#   (NP a/DT guid/JJ tour/NN)
#   (PP of/IN (NP the/DT great/JJ wall/NN))
#   (PP of/IN (NP china/NN))
#   ./.
#   yao/CC
#   creat/VB
#   (NP a/DT person/NN foundat/NN)
#   (PP in/IN (NP late/JJ june/NN))
#   ,/,
#   say/VBP
#   it/PRP
#   (NP first/JJ project/NN)
#   would/MD
#   help/VB
#   (NP children/NNS)
#   left/VBN
#   (NP homeless/NN)
#   (PP by/IN (NP the/DT earthquak/NN))
#   (PP in/IN (NP sichuan/JJ provinc/NN))
#   ./.
#   (NP nigerian/JJ presid/NN olusegun/NN obasanjo/NN)
#   has/VBZ
#   (NP urg/JJ rich/JJ nation/NN)
#   to/TO
#   give/VB
#   more/JJR
#   (NP aid/NN)
#   to/TO
#   africa/VB
#   (PP as/IN (NP leader/NN))
#   (PP from/IN (NP the/DT group/NN))
#   of/IN
#   eight/CD
#   (NP gather/NNS)
#   (PP in/IN (NP scotland/NN))
#   (PP for/IN (NP a/DT summit/NN focus/NN))
#   (PP on/IN (NP lift/NN the/DT contin/NN))
#   out/IN
#   (PP of/IN (NP poverti/NN))
#   ./.
#   (NP mr./NN obasanjo/NNP)
#   told/VBD
#   (NP a/DT london/JJ meet/NN)
#   (PP of/IN (NP the/DT busi/JJ action/NN))
#   (PP for/IN (NP africa/NN))
#   (PP that/IN (NP the/DT contin/NN))
#   is/VBZ
#   hope/VBN
#   (PP about/IN (NP decis/NN))
#   that/WDT
#   will/MD
#   be/VB
#   made/VBN
#   (PP by/IN (NP g8/JJ leader/NN))
#   on/IN
#   better/JJR
#   (NP trade/NN access/NN)
#   and/CC
#   (NP increas/NNS aid/NN)
#   to/TO
#   africa/VB
#   ./.
#   he/PRP
#   also/RB
#   welcom/VBD
#   (NP a/DT plan/NN)
#   to/TO
#   wipe/VB
#   out/RP
#   $/$
#   40/CD
#   billion/CD
#   (NP worth/NN)
#   (PP of/IN (NP debt/NN owe/NN))
#   by/IN
#   18/CD
#   (PP of/IN (NP the/DT world/NN))
#   's/POS
#   poorest/JJS
#   (NP nation/NN)
#   ./.
#   (NP mr./NN obasanjo/NNP)
#   said/VBD
#   (NP african/JJ nation/NN)
#   are/VBP
#   (NP commit/NN)
#   to/TO
#   democraci/VB
#   ,/,
#   (NP good/JJ govern/NN)
#   and/CC
#   (NP end/NN corrupt/NN)
#   ./.
#   (NP befor/JJ head/NN)
#   to/TO
#   scotland/VB
#   (PP for/IN (NP the/DT summit/NN))
#   ,/,
#   (NP presid/NN bush/NN)
#   and/CC
#   (NP danish/JJ prime/JJ minist/NN ander/NN fogh/NN rasmussen/NN)
#   said/VBD
#   (NP increas/JJ aid/NN)
#   to/TO
#   africa/VB
#   must/MD
#   be/VB
#   tie/VBN
#   to/TO
#   (NP good/JJ govern/NN)
#   and/CC
#   (NP effort/NN)
#   to/TO
#   fight/VB
#   (NP corrupt/NN)
#   ./.
#   (NP increas/JJ number/NN)
#   (PP of/IN (NP costum/NN urchin/NNS))
#   are/VBP
#   sent/VBN
#   to/TO
#   parti/VB
#   rather/RB
#   than/IN
#   door/VB
#   to/TO
#   door/VB
#   (NP some/DT religi/NN famili/NN object/NN)
#   to/TO
#   (NP the/DT holiday/NN entir/NN)
#   ,/,
#   say/VBP
#   that/IN
#   it/PRP
#   celebr/VBZ
#   (NP evil/JJ)
#   and/CC
#   (NP the/DT devil/NN)
#   ./.
#   (NP increas/JJ number/NN)
#   (PP of/IN (NP porch/NN light/NN))
#   are/VBP
#   left/VBN
#   off/RP
#   (PP in/IN (NP some/DT neighborhood/NN))
#   ,/,
#   too/RB
#   -/:
#   (NP signal/NN)
#   (PP that/IN (NP the/DT household/NN))
#   will/MD
#   not/RB
#   welcom/VB
#   (NP trick-or-treat/JJ)
#   -/:
#   (NP becaus/NN the/DT resid/NN)
#   are/VBP
#   annoy/VBN
#   (PP by/IN (NP gravelli/NN voic/NN beggar/NN))
#   (PP in/IN (NP frighten/JJ costum/NN))
#   who/WP
#   continu/VBZ
#   to/TO
#   come/VB
#   (NP knock/NN)
#   ,/,
#   well/RB
#   into/IN
#   their/PRP$
#   (NP teen/NN)
#   ./.
#   and/CC
#   (PP in/IN (NP a/DT tight/JJ economi/NN))
#   ,/,
#   (NP some/DT)
#   resid/VBP
#   (NP no/DT)
#   longer/RBR
#   want/VBP
#   to/TO
#   go/VB
#   to/TO
#   (NP the/DT time/NN)
#   ,/,
#   (NP troubl/NN)
#   ,/,
#   and/CC
#   (NP expens/NNS)
#   (PP of/IN (NP buy/NN candi/NN))
#   and/CC
#   decor/VB
#   their/PRP$
#   (NP hous/JJ)
#   (PP for/IN (NP halloween/NN))
#   ./.
#   (NP the/DT upshot/JJ)
#   is/VBZ
#   (PP that/IN (NP come/JJ dusk/NN this/DT sunday/JJ night/NN))
#   (PP across/IN (NP america/NN))
#   ,/,
#   (NP littl/JJ ghoul/NN)
#   and/CC
#   (NP make-believ/JJ starlet/NN)
#   will/MD
#   be/VB
#   about/RB
#   ./.
#   like/IN
#   ,/,
#   though/RB
#   ,/,
#   not/RB
#   as/RB
#   (NP mani/NN)
#   (PP as/IN (NP last/JJ halloween/NN))
#   ./.
#   (NP the/DT unit/NN state/NN)
#   has/VBZ
#   transfer/VBN
#   two/CD
#   (NP detaine/NN)
#   from/IN
#   it/PRP
#   militari/VBZ
#   (NP prison/NN)
#   (PP at/IN (NP guantanamo/NN bay/NN))
#   ,/,
#   (NP cuba/NN)
#   ,/,
#   to/TO
#   (NP other/JJ countri/NN)
#   ./.
#   (NP the/DT defens/NNS depart/NN)
#   said/VBD
#   (NP monday/NN)
#   (PP that/IN (NP abdul/JJ aziz/NN naji/NN))
#   has/VBZ
#   been/VBN
#   sent/VBN
#   back/RB
#   to/TO
#   his/PRP$
#   (NP nativ/JJ algeria/NNS)
#   ,/,
#   (PP while/IN (NP abd-al-nisr/JJ moham/NNS khantumani/NN))
#   was/VBD
#   resettl/VBN
#   (PP in/IN (NP cape/NN verd/NN))
#   ./.
#   (NP a/DT statement/NN)
#   said/VBD
#   (NP the/DT u.s./JJ coordin/NN)
#   (PP with/IN (NP the/DT))
#   two/CD
#   (NP countri/NN)
#   '/''
#   (NP govern/JJ)
#   to/TO
#   ensur/VB
#   (NP a/DT secur/NN transfer/NN)
#   ./.
#   (NP the/DT guantanamo/NN prison/NN hous/JJ alleg/JJ terrorist/NN)
#   ,/,
#   mani/FW
#   held/VBN
#   (PP for/IN (NP year/NN))
#   (PP without/IN (NP trial/NN))
#   ./.
#   (NP the/DT facil/NN)
#   has/VBZ
#   been/VBN
#   (NP wide/JJ critic/NN)
#   (PP by/IN (NP human/JJ right/JJ group/NN))
#   ./.
#   (NP presid/NN barack/NN obama/NN order/NN the/DT facil/NN)
#   to/TO
#   be/VB
#   shut/VBN
#   down/RP
#   (PP within/IN (NP a/DT year/NN))
#   after/IN
#   he/PRP
#   took/VBD
#   offic/RP
#   (PP in/IN (NP januari/NN))
#   2009/CD
#   ./.
#   (NP howev/NN)
#   ,/,
#   (NP the/DT deadlin/NN pass/NN)
#   (PP amid/IN (NP difficulti/NN))
#   (PP in/IN (NP find/JJ place/NN))
#   to/TO
#   put/VB
#   (NP the/DT detaine/NN)
#   ./.
#   more/JJR
#   than/IN
#   40/CD
#   (NP other/JJ countri/NNS)
#   have/VBP
#   accept/VBN
#   at/IN
#   least/JJS
#   one/CD
#   (NP prison/NN)
#   ./.
#   (NP the/DT u.s./JJ)
#   say/VBP
#   178/CD
#   (NP detaine/NN remain/NN)
#   (PP at/IN (NP the/DT facil/NN))
#   ./.
#   (NP zambia/NN)
#   's/POS
#   (NP economi/NN)
#   has/VBZ
#   experienc/VBN
#   (NP strong/JJ growth/NN)
#   (PP in/IN (NP recent/JJ year/NN))
#   ,/,
#   (PP with/IN (NP real/JJ gdp/NNS growth/NN))
#   in/IN
#   2005/CD
#   -/:
#   10/CD
#   about/IN
#   6/CD
#   (NP %/NN)
#   (PP per/IN (NP year/NN))
#   ./.
#   (NP privat/NN)
#   (PP of/IN (NP government-own/JJ copper/NN mine/NN))
#   (PP in/IN (NP the/DT))
#   1990s/CD
#   reliev/VBD
#   (NP the/DT govern/NN)
#   (PP from/IN (NP cover/NN))
#   mammoth/CC
#   (NP loss/NN generat/NN)
#   (PP by/IN (NP the/DT industri/NN))
#   and/CC
#   (NP great/JJ increas/JJ copper/NN mine/NN output/NN)
#   and/CC
#   (NP profit/NN)
#   to/TO
#   spur/VB
#   (NP econom/JJ growth/NN)
#   ./.
#   (NP copper/NN output/NN)
#   has/VBZ
#   increas/VBN
#   steadili/RB
#   (NP sinc/JJ)
#   2004/CD
#   ,/,
#   (NP due/JJ)
#   to/TO
#   higher/JJR
#   (NP copper/NN price/NN)
#   and/CC
#   (NP foreign/JJ invest/NN)
#   ./.)

# %%
stemmed,postags  = zip(*sent)
df["Word"] = stemmed

# %%
df["Tag"] = df["Tag"].replace(
    {"B-per":"per",
     "I-per":"per",
          "B-event":"event",
          "I-event":"event",
          "B-geo":"geo",
          "I-geo":"geo",
          "B-gpe":"gpe",
          "I-gpe":"gpe",
          "B-obj":"obj",
          "I-obj":"obj",
          "B-org":"org",
          "I-org":"org",
          "B-time":"time",
          "I-time":"time"
    }
)

# %%
df.head()
# Out:
#      Word   POS  Tag
# 0  presid   NNP  per
# 1  karzai   NNP  per
# 2   thank   VBD    O
# 3     his  PRP$    O
# 4    alli   NNS    O

# %%
df = df[df.Tag != "O"]

# %%
df = df[(df.POS == "O") | (df.POS == "NN") | (df.POS == "NNP") | (df.POS == "NNS") | (df.POS == "NNPS") |
        (df.POS == "CD") |
        (df.POS == "JJ") | (df.POS == "JJR") | (df.POS == "JJS")]

# %%
df.head()
# Out:
#        Word  POS  Tag
# 0    presid  NNP  per
# 1    karzai  NNP  per
# 15     nato  NNP  org
# 17   afghan   JJ  gpe
# 20  british  NNP  org

# %%
df_probab = df.groupby("Word").Tag.value_counts()

# %%
for index, value in df_probab.items():
    if index[0] == "nato":
        print(index, value)
# Out:
# ('nato', 'org') 87
# ('nato', 'geo') 1

# %%
for s in cs.subtrees(lambda t: t.label() == "NP"):
    for word, pos in s.leaves():
        print(df_probab[])
